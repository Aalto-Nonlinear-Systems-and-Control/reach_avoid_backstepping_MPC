# %%
import math
import numpy as np
import casadi as ca
import sympy as sp
import matplotlib.pyplot as plt
import importlib
import time
import sys
import csv
from pathlib import Path

from k1_dubins_car_copy import k1_0, k1_1, y, val_lambda, val_delta

# %%
k1_0_sym = k1_0
k1_1_sym = k1_1
lam_val = val_lambda  #float(getattr(k1mod, 'val_lambda', 1e-5))
delta_val = val_delta #float(getattr(k1mod, 'val_delta', 0.0))

print("==== k1 sympy expressions ====")
print("k1_0_sym:", k1_0_sym)
print("k1_1_sym:", k1_1_sym)

nx = 4
nu = 2
DT = 0.00005
HORIZON = 8
MU_1 = 4000
U_MIN = np.array([-1000000000.0, -1000000000.0])
U_MAX = np.array([ 1000000000.0,  1000000000.0])
EPS_G_INV = 1e-6   # for Tikhonov regularization of G inverse

# weights for MPC cost
Qy = 10.0       # weight for output tracking (scalar)
R_u = 0.01     # control effort weight
ALPHA = 1.0   # weight for ||u - k(x)||^2 (stage)


# Good Params: dt = 0.00005, HORIZON=8, MU_1=4000, ALPHA=1.0, R_u=0.01, Qy=10.0 (all traj success)

# goal in output space (y)
GOAL = np.array([-1.841, 0])

# solver options
IPOPT_MAX_CPU = 1.5
IPOPT_TOL = 1e-6

# logging file
LOG_CSV = "mpc_upgraded_log.csv"
# Out:
# ==== k1 sympy expressions ====
# k1_0_sym: -0.19714*y0**4 + 3.7662e-17*y0**3*y1 - 1.9504*y0**3 + 0.57221*y0**2*y1**2 + 1.2506e-16*y0**2*y1 - 1.1551*y0**2 + 6.3799e-16*y0*y1**3 - 0.40378*y0*y1**2 - 1.371e-16*y0*y1 + 6.8054*y0 - 24.8899*y1**4 - 2.8172e-17*y1**3 - 2.4721*y1**2 - 4.6193e-16*y1 + 6.4481
# k1_1_sym: -3.881e-16*y0**4 + 24.6136*y0**3*y1 + 9.9483e-17*y0**3 + 1.0575e-16*y0**2*y1**2 - 1.3983*y0**2*y1 - 1.011e-15*y0**2 - 0.70475*y0*y1**3 - 1.0488e-16*y0*y1**2 + 2.3469*y0*y1 + 2.0959e-16*y0 + 7.0033e-18*y1**4 - 2.0483*y1**3 - 7.7029e-17*y1**2 + 7.0416*y1 + 5.7487e-16

# %%
# Sympy symbols for conversion
y0_s, y1_s = sp.symbols('y0 y1')
x0_s, x1_s, x2_s, x3_s = sp.symbols('x0 x1 x2 x3')

# psi (safe set) and phi (target) as given previously
# psi(y) = a*(R - y2)^2 - b*y1 - (y1^4 + y2^4 - R^2)^2
R_val = 3.5
a_val = 2.0
b_val = 1.5
# psi_sym = a_val * (R_val - y1_s)**2 - b_val * y0_s - (y0_s**4 + y1_s**4 - R_val**2)**2
# phi_sym = (y0_s + 0.5)**2 + ((y1_s + 1.9) / 0.5)**2 - 1

psi_sym = - (y0_s**4 + y1_s**4 - 16) * (y0_s**4 + y1_s**4 - 8)
phi_sym = ((y0_s + 1.841) / 0.5)**2 + (y1_s)**2  - 0.1

# lambdify for diagnostic numeric evaluation (fast)
psi_func_numpy = sp.lambdify((y0_s, y1_s), psi_sym, 'numpy')
phi_func_numpy = sp.lambdify((y0_s, y1_s), phi_sym, 'numpy')

# %%
def sympy_poly_to_casadi_SX(sym_expr, sym_vars=(y0_s, y1_s), cas_vars=None):
    """
    Convert a SymPy polynomial (in sym_vars) to a CasADi SX expression in cas_vars ordering.
    Avoid heavy symbolic simplify operations.
    """
    if cas_vars is None:
        cas_vars = [ca.SX.sym('y0'), ca.SX.sym('y1')]
    poly = sp.Poly(sp.expand(sym_expr), *sym_vars)
    # poly = sp.Poly(sym_expr, *sym_vars)
    expr_val = ca.SX(0)
    for mon_exps, coeff in poly.as_dict().items():
        coeff_f = float(sp.N(coeff))
        term = ca.SX(coeff_f)
        for idx, e in enumerate(mon_exps):
            if e != 0:
                term = term * (cas_vars[idx] ** int(e))
        expr_val = expr_val + term
    return expr_val

# CasADi symbolic vars
x_c = ca.SX.sym('x', nx)   # full state symbol
u_c = ca.SX.sym('u', nu)
y_c = ca.vertcat(x_c[0], x_c[1])  # y = h(x)

# Build psi_cas in terms of y_c
psi_cas = sympy_poly_to_casadi_SX(psi_sym, (y0_s, y1_s), cas_vars=[y_c[0], y_c[1]])

# Build k1_cas(y) in terms of y components
k1_0_cas = sympy_poly_to_casadi_SX(k1_0_sym, (y0_s, y1_s), cas_vars=[y_c[0], y_c[1]])
print("k1_0_cas:", k1_0_cas)
k1_1_cas = sympy_poly_to_casadi_SX(k1_1_sym, (y0_s, y1_s), cas_vars=[y_c[0], y_c[1]])
print("k1_1_cas:", k1_1_cas)
k1_cas = ca.vertcat(k1_0_cas, k1_1_cas)

# Build Dy_psi as CasADi (gradient of psi wrt y)
dpsi_dy0_cas = ca.jacobian(psi_cas, y_c)[0]  # returns [dpsi/dy0, dpsi/dy1] as row, so use jacobian directly
dpsi_cas = ca.jacobian(psi_cas, y_c).T  # 2x1

# Build Dk1(y) as CasADi (2x2 Jacobian)
Dk1_cas = ca.jacobian(k1_cas, y_c)  # 2x2 matrix (each row derivative wrt y)

# Build CasADi expressions for Lfh(x), G(x), and k_full(x) (full-state backstepping controller)
# k(x) = G^{-1} [ mu * Dy_psi + Dk1 * Lfh + (lambda/2)*(Lfh - k1) ]
# Use Tikhonov regularization: Ginv = (G^T G + eps I)^{-1} G^T
# Lfh_cas (2x1)
Lfh_cas = ca.vertcat(x_c[3] * ca.cos(x_c[2]), x_c[3] * ca.sin(x_c[2]))

# G(x) as CasADi SX 2x2
# Derived earlier: G = [[ -v*sinθ, cosθ],
#                       [  v*cosθ, sinθ]]
G11 = -x_c[3] * ca.sin(x_c[2])
G12 = ca.cos(x_c[2])
G21 =  x_c[3] * ca.cos(x_c[2])
G22 = ca.sin(x_c[2])
G_cas = ca.vertcat( ca.horzcat(G11, G12), ca.horzcat(G21, G22) )  # 2x2

# Tikhonov-regularized inverse: Ginv = (G^T G + eps I)^{-1} G^T
eps_reg = EPS_G_INV
GtG = ca.mtimes(G_cas.T, G_cas)
GtG_reg = GtG + eps_reg * ca.SX.eye(2)
GtG_reg_inv = ca.inv(GtG_reg)   # 2x2
Ginv_cas = ca.mtimes(GtG_reg_inv, G_cas.T)

# k1 at x (substitute y = x[0:2]) => since k1_cas uses y_c which equals x_c[0:2], we can use k1_cas directly
k1_at_x_cas = k1_cas  # depends on y_c which is x_c[0:2]

# Dk1 * Lfh (2x1)
Dk1Lfh_cas = ca.mtimes(Dk1_cas, Lfh_cas)

# Dy_psi at x_c
Dy_psi_at_x_cas = dpsi_cas  # depends on y_c which equals x_c[0:2]

# Build RHS and k_full_cas
rhs_k_cas = MU_1 * Dy_psi_at_x_cas + Dk1Lfh_cas + (lam_val/2.0) * (Lfh_cas - k1_at_x_cas)
k_full_cas = ca.mtimes(Ginv_cas, rhs_k_cas)  # 2x1 CasADi SX vector

# Make a CasADi function for k_full for diagnostics if needed
k_full_fun = ca.Function('k_full_fun', [x_c], [k_full_cas], ['x'], ['k'])
k1_fun = ca.Function('k1_fun', [x_c], [k1_cas], ['x'], ['k'])
# Out:
# k1_0_cas: ((((((((((((((6.4481+(-4.6193e-16*x_1))+(-2.4721*sq(x_1)))+(-2.8172e-17*(x_1*sq(x_1))))+(-24.8899*sq(sq(x_1))))+(6.8054*x_0))+((-1.371e-16*x_0)*x_1))+((-0.40378*x_0)*sq(x_1)))+((6.3799e-16*x_0)*(x_1*sq(x_1))))+(-1.1551*sq(x_0)))+((1.2506e-16*sq(x_0))*x_1))+((0.57221*sq(x_0))*sq(x_1)))+(-1.9504*(x_0*sq(x_0))))+((3.7662e-17*(x_0*sq(x_0)))*x_1))+(-0.19714*sq(sq(x_0))))
# k1_1_cas: ((((((((((((((5.7487e-16+(7.0416*x_1))+(-7.7029e-17*sq(x_1)))+(-2.0483*(x_1*sq(x_1))))+(7.0033e-18*sq(sq(x_1))))+(2.0959e-16*x_0))+((2.3469*x_0)*x_1))+((-1.0488e-16*x_0)*sq(x_1)))+((-0.70475*x_0)*(x_1*sq(x_1))))+(-1.011e-15*sq(x_0)))+((-1.3983*sq(x_0))*x_1))+((1.0575e-16*sq(x_0))*sq(x_1)))+(9.9483e-17*(x_0*sq(x_0))))+((24.6136*(x_0*sq(x_0)))*x_1))+(-3.881e-16*sq(sq(x_0))))

# %%
# Single Integrator Streamline Plotting Code

import numpy as np
import matplotlib.pyplot as plt
import casadi as ca
import math
import sys

xrange = [-2.5, 2.5]      # match ranges you used in MATLAB
yrange = [-2.5, 2.5]
density_grid = 100        # number of points per axis (use same in MATLAB for matching)
numStart = 15             # number of start points per direction (MATLAB default was 15)
theta_stream = 0.0        # placeholder (not used by k1 if k1 only depends on (y0,y1))
v_stream = 0.85           # placeholder
normalize = False         # MATLAB did not normalize; set True only if you normalized in MATLAB
quiver_subsample = 8      # subsample for quiver to avoid clutter

# color that matches your MATLAB RGB
matlab_grey = (146/255, 149/255, 145/255)

# safe epsilon
_eps = 1e-12

xs = np.linspace(xrange[0], xrange[1], density_grid)
ys = np.linspace(yrange[0], yrange[1], density_grid)
# XX,YY shapes: (len(ys), len(xs)) — rows correspond to y, cols correspond to x
XX, YY = np.meshgrid(xs, ys)   # indexing='xy' default
ZZ = np.zeros_like(XX)
PH = np.zeros_like(XX)
for ii in range(XX.shape[0]):
    for jj in range(XX.shape[1]):
        ZZ[ii,jj] = float(psi_func_numpy(XX[ii,jj], YY[ii,jj]))
        PH[ii,jj] = float(phi_func_numpy(XX[ii,jj], YY[ii,jj]))

# initialize U,V with shape (len(ys), len(xs))
U = np.zeros_like(XX, dtype=float)
V = np.zeros_like(XX, dtype=float)

try:
    # number of rows expected by k1_fun input
    # note: k1_fun.size_in(0) gives (nrows, ncols) shape of input (CasADi >=3.5+)
    shape_in = k1_fun.size_in(0)  # returns tuple (nrows, ncols) for a MX/DM input
    # shape_in may be (n,1) for column vector input
except Exception:
    # Fallback: try evaluating once with a 2-vector to see accepted shape
    shape_in = None

# Flattened grid point count
N = XX.size

# Build candidate batched input depending on expectation:
# - If k1_fun expects a 2x1 or 4x1 input, we will provide an (n x N) DM where n is rows.
#   If k1_fun expects 4 rows (y0,y1,theta,v), fill theta and v with chosen constants.
# We'll try both 2-row and 4-row batch calls, catching exceptions.

def try_batch_eval(num_rows):
    if num_rows == 2:
        # 2 rows: y0, y1
        X_batch = np.vstack([XX.ravel(), YY.ravel()])   # shape (2, N)
    elif num_rows == 4:
        X_batch = np.vstack([XX.ravel(), YY.ravel(),
                             theta_stream * np.ones(N),
                             v_stream * np.ones(N)])        # shape (4, N)
    else:
        raise RuntimeError("Unsupported num_rows proposal: %d" % num_rows)

    try:
        X_dm = ca.DM(X_batch)   # convert to CasADi DM for batch evaluation
        out = k1_fun(X_dm)      # call: may return DM or list
        # Extract DM if returned in list/dict-like
        if isinstance(out, (list, tuple)):
            k_dm = out[0]
        elif isinstance(out, dict):
            # sometimes CasADi functions with named outputs return a dict
            k_dm = next(iter(out.values()))
        else:
            k_dm = out
        k_numpy = np.array(k_dm)  # shape expected (2, N) or (m, N)
        # If shape is (2,N) or (N,2) handle accordingly:
        if k_numpy.shape[0] == 2 and k_numpy.ndim == 2:
            U_flat = k_numpy[0, :].astype(float)
            V_flat = k_numpy[1, :].astype(float)
        elif k_numpy.shape[1] == 2 and k_numpy.ndim == 2:
            # sometimes output is (N,2)
            U_flat = k_numpy[:, 0].astype(float)
            V_flat = k_numpy[:, 1].astype(float)
        else:
            # attempt flatten and take first two components per column
            # reshape to (n_outputs, N)
            k_numpy_flat = k_numpy.reshape((-1, N))
            U_flat = k_numpy_flat[0, :].astype(float)
            V_flat = k_numpy_flat[1, :].astype(float)

        return U_flat, V_flat
    except Exception as e:
        raise

batch_success = False
for rows_try in (2, 4):
    try:
        U_flat, V_flat = try_batch_eval(rows_try)
        # reshape back to grid shape (len(ys), len(xs))
        U = U_flat.reshape(XX.shape)
        V = V_flat.reshape(XX.shape)
        batch_success = True
        # print debug info
        print(f"Batch evaluation succeeded with {rows_try} rows input.")
        break
    except Exception as e:
        #print(f"Batch attempt with {rows_try} rows failed: {e}")
        continue

# If batch failed, fallback to double loop
if not batch_success:
    print("Batch evaluation failed: falling back to double loop evaluation (slower).", file=sys.stderr)
    for i in range(XX.shape[0]):      # rows -> y
        for j in range(XX.shape[1]):  # cols -> x
            # Build single column input for k1_fun
            # Try to call with 2-length first then 4-length if needed
            x2 = np.array([XX[i,j], YY[i,j]])
            x4 = np.array([XX[i,j], YY[i,j], theta_stream, v_stream])
            assigned = False
            for x_try in (x2, x4):
                try:
                    out = k_full_fun(x_try)
                    if isinstance(out, (list, tuple)):
                        out0 = out[0]
                    else:
                        out0 = out
                    out_arr = np.array(out0).flatten()
                    U[i,j] = float(out_arr[0])
                    V[i,j] = float(out_arr[1])
                    assigned = True
                    break
                except Exception:
                    continue
            if not assigned:
                # on failure set zero (like you did): but log if many failures happen
                U[i,j] = 0.0
                V[i,j] = 0.0

if normalize:
    mag = np.sqrt(U**2 + V**2)
    mag[mag < _eps] = 1.0
    U_plot = U / mag
    V_plot = V / mag
else:
    U_plot = U
    V_plot = V

startx = np.linspace(xrange[0] * 0.9, xrange[1] * 0.9, numStart)
starty = np.linspace(yrange[0] * 0.9, yrange[1] * 0.9, numStart)
sx, sy = np.meshgrid(startx, starty)
start_pts = np.vstack((sx.ravel(), sy.ravel())).T   # shape (Nstart, 2)

plt.figure(figsize=(8,6))
plt.streamplot(xs, ys, U_plot, V_plot,
               start_points=start_pts,
               density=4.0,
               color=matlab_grey,
               linewidth=0.8,
               arrowsize=0.7)

plt.contour(XX, YY, ZZ, levels=[0.0], colors='k', linewidths=1.2)
plt.contour(XX, YY, PH, levels=[0.0], colors='r', linestyles='--')

plt.title(f"Streamlines (MATLAB-like) — normalize={normalize}")
plt.xlabel('y1')   # match your MATLAB labels
plt.ylabel('y2')
plt.xlim(xrange)
plt.ylim(yrange)
plt.gca().set_box_aspect(1.0)  # keep axes equal-ish
plt.grid(True)
plt.show()
# Out:
# Batch evaluation succeeded with 4 rows input.

# %%
# Also create Psi_cas expression (terminal certificate)
diff_cas = Lfh_cas - k1_at_x_cas
Psi_cas = psi_cas - (1.0 / (2.0 * MU_1)) * ca.dot(diff_cas, diff_cas)
Psi_fun_cas = ca.Function('Psi_fun', [x_c], [Psi_cas], ['x'], ['Psi'])


# discrete dynamics CasADi function f_disc(x,u) = x + DT*(f(x) + g*u)
f_cas = ca.SX.zeros(nx, 1)
f_cas[0] = x_c[3] * ca.cos(x_c[2])
f_cas[1] = x_c[3] * ca.sin(x_c[2])
f_cas[2] = 0
f_cas[3] = 0
g_cas = ca.SX.zeros(nx, nu)
g_cas[2, 0] = 1
g_cas[3, 1] = 1
# xnext_cas = x_c + DT * (f_cas + ca.mtimes(g_cas, u_c))
def casadi_rk4_step(x, u):
    DTc = DT
    f1 = ca.vertcat(x[3]*ca.cos(x[2]), x[3]*ca.sin(x[2]), u[0], u[1])
    x2 = x + 0.5*DTc * f1
    f2 = ca.vertcat(x2[3]*ca.cos(x2[2]), x2[3]*ca.sin(x2[2]), u[0], u[1])
    x3 = x + 0.5*DTc * f2
    f3 = ca.vertcat(x3[3]*ca.cos(x3[2]), x3[3]*ca.sin(x3[2]), u[0], u[1])
    x4 = x + DTc * f3
    f4 = ca.vertcat(x4[3]*ca.cos(x4[2]), x4[3]*ca.sin(x4[2]), u[0], u[1])
    return x + (DTc/6.0)*(f1 + 2*f2 + 2*f3 + f4)

xnext_cas = casadi_rk4_step(x_c, u_c)

f_disc = ca.Function('f_disc', [x_c, u_c], [xnext_cas], ['x', 'u'], ['xnext'])

# Build one-time NMPC solver
# Decision vars: X (nx x N), U (nu x N)
# Constraints:
# - dynamics: X[:,k+1] = f_disc(X[:,k], U[:,k])
# - safety for each predicted state: psi(h(X[:,k])) >= 0  (hard)
# - terminal: Psi(X[:,N-1]) >= 0  (note indexing: X columns correspond to x1..xN)
# Objective:
# sum_k [ ||y_k - GOAL||^2 * Qy + R_u ||U_k||^2 + ALPHA * ||U_k - k_full(X_k)||^2 ]
def build_mpc_solver(N):
    X = ca.SX.sym('X', nx, N)   # predicted x1..xN
    U = ca.SX.sym('U', nu, N)   # u0..u_{N-1}
    P = ca.SX.sym('P', nx)      # parameter current state x0

    opt_vars = ca.vertcat(ca.reshape(X, -1, 1), ca.reshape(U, -1, 1))

    g_list = []
    obj = ca.SX(0)

    for k in range(N):
        # define xk (the state used for computing U_k)
        if k == 0:
            xk = P  # current state as parameter
        else:
            xk = X[:, k-1]   # predicted state x_k

        uk = U[:, k]

        # predict next state equality: X[:, k] == f_disc(xk, uk)
        xkpred = f_disc(xk, uk)
        g_list.append(X[:, k] - xkpred)

        # stage cost
        y_k = X[0:2, k]  # predicted output at stage k (x1,x2)
        # tracking
        obj = obj + Qy * ca.dot(y_k - ca.DM(GOAL), y_k - ca.DM(GOAL))
        # control effort
        obj = obj + R_u * ca.dot(uk, uk)

        # bias toward backstepping controller at stage k:
        # build k_full evaluated at xk (use k_full_cas, but substitute x_c -> xk)
        k_full_at_xk = ca.substitute([k_full_cas], [x_c], [xk])[0]
        diff_u = uk - k_full_at_xk
        obj = obj + ALPHA * ca.dot(diff_u, diff_u)

        # safety constraint for predicted state X[:,k]
        # evaluate psi at (X[0,k], X[1,k])
        psi_at_stage = ca.substitute([psi_cas], [y_c[0], y_c[1]], [X[0, k], X[1, k]])[0]
        # enforce psi_at_stage >= 0 (we will set lbg accordingly)
        g_list.append(psi_at_stage) 

    # Terminal constraint: Psi(X[:,N-1]) >= 0
    xN = X[:, N-1]
    Psi_at_end = ca.substitute([Psi_cas], [x_c], [xN])[0]
    g_list.append(Psi_at_end)

    # stack constraints
    g_all = ca.vertcat(*g_list)

    nlp = {'x': opt_vars, 'f': obj, 'g': g_all, 'p': P}
    opts = {
        'ipopt': {
            'print_level': 0,
            'max_cpu_time': IPOPT_MAX_CPU,
            'tol': IPOPT_TOL,
            'acceptable_tol': 1e-4,
        },
        'print_time': False
    }
    # create solver
    solver = ca.nlpsol('solver', 'ipopt', nlp, opts)

    nxN = nx * N
    nconstr = int(g_all.numel())
    return solver, nxN, nconstr

solver, nxN, nconstr = build_mpc_solver(HORIZON)

def default_bounds_and_guesses(N):
    nxN = nx * N
    nuN = nu * N
    nvars = nxN + nuN
    x0_guess = np.zeros(nvars)
    lbx = -1e20 * np.ones(nvars)
    ubx =  1e20 * np.ones(nvars)
    # set U bounds
    for k in range(N):
        idx = nxN + k*nu
        lbx[idx:idx+nu] = U_MIN
        ubx[idx:idx+nu] = U_MAX
    return x0_guess, lbx, ubx

x0_guess_template, lbx, ubx = default_bounds_and_guesses(HORIZON)

_prev_w_opt = None
use_warmstart = False

def make_initial_guess(x0, N, prev_w_opt=None, use_warmstart=False):
    nxN = nx * N
    nuN = nu * N
    nvars = nxN + nuN
    if use_warmstart and prev_w_opt is not None and prev_w_opt.size == nvars:
        return prev_w_opt.copy()
    # else create structured guess: predicted X all equal to x0, U zeros
    guess = np.zeros(nvars)
    for k in range(N):
        idx = k * nx
        guess[idx:idx+nx] = x0
    return guess

# solve_mpc_once: build appropriate lbg/ubg, call solver with warm-start, return u0 and diagnostic info
def solve_mpc_once(x0, N=HORIZON):
    global _prev_w_opt
    p = x0.copy()
    # build initial guess
    x0_guess_local = make_initial_guess(x0, N, _prev_w_opt, use_warmstart)
    # compose lbg, ubg consistent with g_list ordering in build_mpc_solver
    # For each k we appended: [ dynamics (nx eq) , psi_at_stage (ineq) ] repeated N times, and final Psi (ineq)
    # So total constraints = N*(nx + 1) + 1(final) , but final was appended as last, so total = N* (nx+1) + 1? Let's re-derive:
    # In build loop per k: g_list.append(X[:,k] - xkpred) --> vector of size nx (equality)
    # then g_list.append(psi_at_stage) --> scalar (inequality)
    # after loop: g_list.append(Psi_at_end) --> scalar (inequality)
    # So stacked g_all has length N*nx + N*1 + 1 = N*nx + N + 1
    total_eq = N * nx
    total_ineq_stage = N
    total_ineq_final = 1
    total_constraints = total_eq + total_ineq_stage + total_ineq_final
    # Build lbg/ubg arrays
    lbg = np.zeros(total_constraints)
    ubg = np.zeros(total_constraints)
    # For equality blocks (dynamics) indices [0 : N*nx) -> lbg=0, ubg=0
    # For stage psi inequalities, they are located after each dynamics block; their indices are:
    # idx = k*(nx + 1) + nx   (if we think in groups). Simpler: we can fill by iterating
    # But easiest is to construct by following the same ordering:
    idx = 0
    for k in range(N):
        # dynamics nx entries
        idx += nx
        # psi inequality scalar
        # set lbg[idx] = 0, ubg[idx] = +inf
        lbg[idx] = 0.0
        ubg[idx] = 1e20
        idx += 1
    # final Psi (last constraint)
    # idx now equals N*nx + N
    lbg[idx] = 0.0
    ubg[idx] = 1e20

    try:
        tic = time.time()
        sol = solver(x0=x0_guess_local, lbx=lbx, ubx=ubx, lbg=lbg, ubg=ubg, p=p)
        elapsed = time.time() - tic
        w_opt = np.array(sol['x']).flatten()
        _prev_w_opt = w_opt.copy()  # warm-start next time
        u0 = w_opt[nxN : nxN + nu].copy()
        # extract X_N for diagnostics
        X_flat = w_opt[0 : nxN]
        xN = X_flat[(N-1)*nx : N*nx].copy()
        # compute diagnostics
        psi_pred_vals = []
        # compute min predicted psi across stages (numeric) for logging
        for k in range(N):
            xk_pred = X_flat[k*nx : (k+1)*nx]
            psi_k = float(sp.N(psi_sym.subs({y0_s: xk_pred[0], y1_s: xk_pred[1]})))
            psi_pred_vals.append(psi_k)
        min_psi_pred = float(np.min(psi_pred_vals))
        psi_terminal = float(sp.N(Psi_cas(xN).full()[0,0])) if False else compute_Psi_numeric_from_numpy(xN)  # fallback numeric
        # objective value
        obj_val = float(sol['f'])
        stats = solver.stats()
        return True, u0, {'xN': xN, 'min_psi_pred': min_psi_pred, 'psi_terminal': psi_terminal, 'obj': obj_val, 'solve_time': elapsed, 'stats': stats}
    except Exception as e:
        return False, None, {'error': str(e)}


# Create lambdified numeric functions for k1 and its derivatives
k1_func_numpy = sp.lambdify((y0_s, y1_s), sp.Matrix([k1_0_sym, k1_1_sym]), 'numpy')
dk1_dy00 = sp.diff(k1_0_sym, y0_s)
dk1_dy01 = sp.diff(k1_0_sym, y1_s)
dk1_dy10 = sp.diff(k1_1_sym, y0_s)
dk1_dy11 = sp.diff(k1_1_sym, y1_s)
dk1_funcs_np = (
    sp.lambdify((y0_s, y1_s), dk1_dy00, 'numpy'),
    sp.lambdify((y0_s, y1_s), dk1_dy01, 'numpy'),
    sp.lambdify((y0_s, y1_s), dk1_dy10, 'numpy'),
    sp.lambdify((y0_s, y1_s), dk1_dy11, 'numpy'),
)

def eval_k1_numpy(y):
    return np.array(k1_func_numpy(y[0], y[1]), dtype=float).reshape((2,))

def compute_Lfh_numpy(x):
    theta = x[2]; v = x[3]
    return np.array([v * math.cos(theta), v * math.sin(theta)], dtype=float)

def compute_Psi_numeric_from_numpy(x):
    # psi(y)
    y = np.array([x[0], x[1]], dtype=float)
    psi_val = float(psi_func_numpy(y[0], y[1]))
    Lfh = compute_Lfh_numpy(x)
    k1_val = eval_k1_numpy(y)
    diff = Lfh - k1_val
    val = psi_val - (1.0 / (2.0 * MU_1)) * float(np.dot(diff, diff))
    return float(val)

# Plant integrator RK4
def rk4_step(xvec, uvec, dt=DT):
    def f_cont(xv, uv):
        return np.array([xv[3]*math.cos(xv[2]), xv[3]*math.sin(xv[2]), uv[0], uv[1]])
    k1 = f_cont(xvec, uvec)
    k2 = f_cont(xvec + 0.5*dt*k1, uvec)
    k3 = f_cont(xvec + 0.5*dt*k2, uvec)
    k4 = f_cont(xvec + dt*k3, uvec)
    return xvec + (dt/6.0)*(k1 + 2*k2 + 2*k3 + k4)


def run_mpc_closed_loop(initial_state, horizon=HORIZON, max_steps=300, log_file=None):
    x = initial_state.copy()
    traj = [x.copy()]
    used = []
    reached = False

    # prepare CSV log
    if log_file is not None:
        csv_f = open(log_file, 'w', newline='')
        csv_writer = csv.writer(csv_f)
        csv_writer.writerow(['step','used','psi_current','min_psi_pred','psi_terminal','obj','solve_time','reached','note'])
    else:
        csv_f = None
        csv_writer = None

    for t in range(max_steps):
        psi_curr = float(psi_func_numpy(x[0], x[1]))
        ok, u0, info = solve_mpc_once(x, N=horizon)
        
        if not ok:
            # infeasible or solver failure -> log and break (no fallback per user request)
            note = f"MPC infeasible or failed at step {t}: {info.get('error')}"
            print(note)
            if csv_writer:
                csv_writer.writerow([t, 'MPC_FAIL', psi_curr, None, None, None, None, False, note])
            break

        # we have a solution accepted; apply u0
        u_apply = np.minimum(np.maximum(np.array(u0).reshape((2,)), U_MIN), U_MAX)
        # print(f"Step {t}: Applying MPC control u={u_apply}")
        used.append('MPC')
        # logging info extraction
        min_psi_pred = info.get('min_psi_pred', None)
        psi_terminal = info.get('psi_terminal', None)
        # print("psi_terminal:", psi_terminal)
        obj_val = info.get('obj', None)
        solve_time = info.get('solve_time', None)

        # apply to plant
        x = rk4_step(x, u_apply, DT)
        traj.append(x.copy())
        
        # check target
        phi_val = float(phi_func_numpy(x[0], x[1]))
        reached = True if (phi_val < 0) else False

        print(f"step {t}: psi_curr={psi_curr:.4e}, min_psi_pred={min_psi_pred:.4e}, psi_term={psi_terminal:.4e}, obj={obj_val:.6f}, solved_in={solve_time:.3f}s")

        # log
        if csv_writer:
            csv_writer.writerow([t, 'MPC', psi_curr, min_psi_pred, psi_terminal, obj_val, solve_time, reached, ''])
        else:
            print(f"step {t}: psi_curr={psi_curr:.4e}, min_psi_pred={min_psi_pred:.4e}, psi_term={psi_terminal:.4e}, obj={obj_val:.6f}, solved_in={solve_time:.3f}s")

        if reached:
            print(f"Reached target at step {t}")
            break

    if csv_f:
        csv_f.close()

    return {'traj': np.array(traj), 'used': used, 'reached': reached}

# %%
if __name__ == "__main__":
    initials = [
        np.array([-1.5, 1.8, -3*math.pi/4, 0.2]),
        np.array([1.35, 1.6, math.pi, 1]),
        np.array([0.0, 1.75, 0*math.pi, 1]),
        np.array([1.5,  -1.4, math.pi, 1]),
        np.array([1.8, 0.1, math.pi/2, 1.5]),
        np.array([1.9, -0.3, -math.pi/2, 2])
    ]
    print(k_full_fun(initials[0]))  # test call
    for x in initials:
        psi_v = float(psi_func_numpy(x[0], x[1]))
        Psi_v = compute_Psi_numeric_from_numpy(x)   # you already have this helper
        print("x:", x, "psi=", psi_v, " Psi=", Psi_v)    

    print("Running upgraded MPC-only closed-loop (no fallback). Logging to", LOG_CSV)
    all_results = []
    for i, init in enumerate(initials):
        print(f"\nTrial {i}, initial = {init}")
        res = run_mpc_closed_loop(init, horizon=HORIZON, max_steps=2000, log_file=f"run_{i}_" + LOG_CSV)
        all_results.append(res)
        print("Result:", "reached" if res['reached'] else "not reached", "steps:", res['traj'].shape[0])
# Out:
# [3.7087e+06, 197888]
# x: [-1.5         1.8        -2.35619449  0.2       ] psi= 3.3256879899999983  Psi= -8.356112783904887
# x: [1.35       1.6        3.14159265 1.        ] psi= 11.484826551210945  Psi= 7.148015575373543
# x: [0.   1.75 0.   1.  ] psi= 9.129867553710938  Psi= 2.1934155115672294
# x: [ 1.5        -1.4         3.14159265  1.        ] psi= 6.415403189999998  Psi= 3.6202262483145238
# x: [1.8        0.1        1.57079633 1.5       ] psi= 13.74309471  Psi= 13.719949961432071
# x: [ 1.9        -0.3        -1.57079633  2.        ] psi= 14.917983960000003  Psi= 14.599169520719487
# Running upgraded MPC-only closed-loop (no fallback). Logging to mpc_upgraded_log.csv
#
# Trial 0, initial = [-1.5         1.8        -2.35619449  0.2       ]
# step 0: psi_curr=3.3257e+00, min_psi_pred=3.1177e+00, psi_term=-1.0000e-08, obj=6925725986163.543945, solved_in=0.281s
# step 1: psi_curr=3.3262e+00, min_psi_pred=3.0494e+00, psi_term=-1.0000e-08, obj=215399263720.695770, solved_in=0.078s
# step 2: psi_curr=3.2346e+00, min_psi_pred=3.2413e+00, psi_term=-1.0000e-08, obj=56553730695.551590, solved_in=0.053s
# step 3: psi_curr=3.4111e+00, min_psi_pred=3.6325e+00, psi_term=-1.0000e-08, obj=24880113939.752930, solved_in=0.028s
# step 4: psi_curr=3.6325e+00, min_psi_pred=3.9401e+00, psi_term=-1.0000e-08, obj=48783861492.839256, solved_in=0.043s
# step 5: psi_curr=3.9401e+00, min_psi_pred=3.6578e+00, psi_term=-1.0000e-08, obj=142092811030.932251, solved_in=0.085s
# step 6: psi_curr=3.6578e+00, min_psi_pred=3.2614e+00, psi_term=-1.0000e-08, obj=25626503993.758923, solved_in=0.043s
# step 7: psi_curr=3.2614e+00, min_psi_pred=3.6543e+00, psi_term=-1.0000e-08, obj=50981060394.421242, solved_in=0.040s
# step 8: psi_curr=3.6543e+00, min_psi_pred=3.6207e+00, psi_term=-1.0000e-08, obj=2721659005.899889, solved_in=0.014s
# step 9: psi_curr=3.6207e+00, min_psi_pred=3.7342e+00, psi_term=-1.0000e-08, obj=2074378189.255549, solved_in=0.016s
# step 10: psi_curr=3.7342e+00, min_psi_pred=3.8353e+00, psi_term=-1.0000e-08, obj=5174518733.928640, solved_in=0.024s
# step 11: psi_curr=3.8353e+00, min_psi_pred=3.9266e+00, psi_term=-1.0000e-08, obj=1217213218.239591, solved_in=0.027s
# step 12: psi_curr=3.9266e+00, min_psi_pred=4.0277e+00, psi_term=-9.9999e-09, obj=1046261611.497462, solved_in=0.013s
# step 13: psi_curr=4.0277e+00, min_psi_pred=4.1198e+00, psi_term=-9.9999e-09, obj=845549450.970602, solved_in=0.011s
# step 14: psi_curr=4.1198e+00, min_psi_pred=4.2017e+00, psi_term=-9.9999e-09, obj=701562267.756237, solved_in=0.008s
# step 15: psi_curr=4.2017e+00, min_psi_pred=4.2741e+00, psi_term=-9.9999e-09, obj=601942727.056984, solved_in=0.010s
# step 16: psi_curr=4.2741e+00, min_psi_pred=4.3382e+00, psi_term=-9.9999e-09, obj=532847690.959312, solved_in=0.010s
# step 17: psi_curr=4.3382e+00, min_psi_pred=4.3950e+00, psi_term=-9.9998e-09, obj=484609434.909889, solved_in=0.010s
# step 18: psi_curr=4.3950e+00, min_psi_pred=4.4458e+00, psi_term=-9.9997e-09, obj=450646594.865235, solved_in=0.012s
# step 19: psi_curr=4.4458e+00, min_psi_pred=4.4916e+00, psi_term=-9.9995e-09, obj=426482490.232179, solved_in=0.010s
# step 20: psi_curr=4.4916e+00, min_psi_pred=4.5334e+00, psi_term=-9.9986e-09, obj=409084073.131688, solved_in=0.011s
# step 21: psi_curr=4.5334e+00, min_psi_pred=4.5721e+00, psi_term=1.8452e-02, obj=396394716.447096, solved_in=0.014s
# step 22: psi_curr=4.5721e+00, min_psi_pred=4.6092e+00, psi_term=1.3331e-01, obj=386506043.044837, solved_in=0.012s
# step 23: psi_curr=4.6092e+00, min_psi_pred=4.6462e+00, psi_term=2.4651e-01, obj=378621414.147837, solved_in=0.013s
# step 24: psi_curr=4.6462e+00, min_psi_pred=4.6830e+00, psi_term=3.5812e-01, obj=371204721.435536, solved_in=0.017s
# step 25: psi_curr=4.6830e+00, min_psi_pred=4.7197e+00, psi_term=4.6819e-01, obj=364115225.953040, solved_in=0.014s
# step 26: psi_curr=4.7197e+00, min_psi_pred=4.7563e+00, psi_term=5.7675e-01, obj=357322317.881406, solved_in=0.011s
# step 27: psi_curr=4.7563e+00, min_psi_pred=4.7928e+00, psi_term=6.8385e-01, obj=350806035.844447, solved_in=0.012s
# step 28: psi_curr=4.7928e+00, min_psi_pred=4.8291e+00, psi_term=7.8954e-01, obj=344548879.529117, solved_in=0.014s
# step 29: psi_curr=4.8291e+00, min_psi_pred=4.8654e+00, psi_term=8.9385e-01, obj=338534965.348560, solved_in=0.011s
# step 30: psi_curr=4.8654e+00, min_psi_pred=4.9016e+00, psi_term=9.9681e-01, obj=332749798.757472, solved_in=0.013s
# step 31: psi_curr=4.9016e+00, min_psi_pred=4.9376e+00, psi_term=1.0985e+00, obj=327180117.542418, solved_in=0.008s
# step 32: psi_curr=4.9376e+00, min_psi_pred=4.9735e+00, psi_term=1.1988e+00, obj=321813758.781452, solved_in=0.008s
# step 33: psi_curr=4.9735e+00, min_psi_pred=5.0093e+00, psi_term=1.2979e+00, obj=316639542.966166, solved_in=0.007s
# step 34: psi_curr=5.0093e+00, min_psi_pred=5.0450e+00, psi_term=1.3958e+00, obj=311647172.532435, solved_in=0.008s
# step 35: psi_curr=5.0450e+00, min_psi_pred=5.0806e+00, psi_term=1.4925e+00, obj=306827142.717108, solved_in=0.009s
# step 36: psi_curr=5.0806e+00, min_psi_pred=5.1161e+00, psi_term=1.5880e+00, obj=302170663.012213, solved_in=0.008s
# step 37: psi_curr=5.1161e+00, min_psi_pred=5.1515e+00, psi_term=1.6824e+00, obj=297669587.763013, solved_in=0.008s
# step 38: psi_curr=5.1515e+00, min_psi_pred=5.1867e+00, psi_term=1.7756e+00, obj=293316354.681785, solved_in=0.008s
# step 39: psi_curr=5.1867e+00, min_psi_pred=5.2219e+00, psi_term=1.8677e+00, obj=289103930.235745, solved_in=0.008s
# step 40: psi_curr=5.2219e+00, min_psi_pred=5.2569e+00, psi_term=1.9588e+00, obj=285025761.022572, solved_in=0.008s
# step 41: psi_curr=5.2569e+00, min_psi_pred=5.2918e+00, psi_term=2.0488e+00, obj=281075730.376714, solved_in=0.008s
# step 42: psi_curr=5.2918e+00, min_psi_pred=5.3266e+00, psi_term=2.1377e+00, obj=277248119.557877, solved_in=0.008s
# step 43: psi_curr=5.3266e+00, min_psi_pred=5.3613e+00, psi_term=2.2256e+00, obj=273537572.964614, solved_in=0.009s
# step 44: psi_curr=5.3613e+00, min_psi_pred=5.3959e+00, psi_term=2.3125e+00, obj=269939066.892623, solved_in=0.009s
# step 45: psi_curr=5.3959e+00, min_psi_pred=5.4303e+00, psi_term=2.3985e+00, obj=266447881.422754, solved_in=0.009s
# step 46: psi_curr=5.4303e+00, min_psi_pred=5.4647e+00, psi_term=2.4834e+00, obj=263059575.078883, solved_in=0.008s
# step 47: psi_curr=5.4647e+00, min_psi_pred=5.4989e+00, psi_term=2.5675e+00, obj=259769961.943037, solved_in=0.008s
# step 48: psi_curr=5.4989e+00, min_psi_pred=5.5329e+00, psi_term=2.6506e+00, obj=256575090.955327, solved_in=0.009s
# step 49: psi_curr=5.5329e+00, min_psi_pred=5.5669e+00, psi_term=2.7328e+00, obj=253471227.160774, solved_in=0.008s
# step 50: psi_curr=5.5669e+00, min_psi_pred=5.6008e+00, psi_term=2.8141e+00, obj=250454834.694740, solved_in=0.008s
# step 51: psi_curr=5.6008e+00, min_psi_pred=5.6345e+00, psi_term=2.8945e+00, obj=247522561.324078, solved_in=0.007s
# step 52: psi_curr=5.6345e+00, min_psi_pred=5.6681e+00, psi_term=2.9741e+00, obj=244671224.383327, solved_in=0.008s
# step 53: psi_curr=5.6681e+00, min_psi_pred=5.7016e+00, psi_term=3.0529e+00, obj=241897797.964076, solved_in=0.009s
# step 54: psi_curr=5.7016e+00, min_psi_pred=5.7350e+00, psi_term=3.1308e+00, obj=239199401.232395, solved_in=0.007s
# step 55: psi_curr=5.7350e+00, min_psi_pred=5.7683e+00, psi_term=3.2080e+00, obj=236573287.763476, solved_in=0.007s
# step 56: psi_curr=5.7683e+00, min_psi_pred=5.8014e+00, psi_term=3.2844e+00, obj=234016835.795093, solved_in=0.008s
# step 57: psi_curr=5.8014e+00, min_psi_pred=5.8345e+00, psi_term=3.3601e+00, obj=231527539.312671, solved_in=0.008s
# step 58: psi_curr=5.8345e+00, min_psi_pred=5.8674e+00, psi_term=3.4350e+00, obj=229102999.887916, solved_in=0.008s
# step 59: psi_curr=5.8674e+00, min_psi_pred=5.9003e+00, psi_term=3.5092e+00, obj=226740919.201810, solved_in=0.008s
# step 60: psi_curr=5.9003e+00, min_psi_pred=5.9330e+00, psi_term=3.5827e+00, obj=224439092.189758, solved_in=0.008s
# step 61: psi_curr=5.9330e+00, min_psi_pred=5.9656e+00, psi_term=3.6556e+00, obj=222195400.753361, solved_in=0.007s
# step 62: psi_curr=5.9656e+00, min_psi_pred=5.9982e+00, psi_term=3.7278e+00, obj=220007807.988960, solved_in=0.008s
# step 63: psi_curr=5.9982e+00, min_psi_pred=6.0306e+00, psi_term=3.7994e+00, obj=217874352.888081, solved_in=0.008s
# step 64: psi_curr=6.0306e+00, min_psi_pred=6.0630e+00, psi_term=3.8703e+00, obj=215793145.469496, solved_in=0.008s
# step 65: psi_curr=6.0630e+00, min_psi_pred=6.0952e+00, psi_term=3.9407e+00, obj=213762362.306380, solved_in=0.008s
# step 66: psi_curr=6.0952e+00, min_psi_pred=6.1274e+00, psi_term=4.0105e+00, obj=211780242.415799, solved_in=0.007s
# step 67: psi_curr=6.1274e+00, min_psi_pred=6.1595e+00, psi_term=4.0798e+00, obj=209845083.480594, solved_in=0.008s
# step 68: psi_curr=6.1595e+00, min_psi_pred=6.1916e+00, psi_term=4.1485e+00, obj=207955238.376789, solved_in=0.007s
# step 69: psi_curr=6.1916e+00, min_psi_pred=6.2235e+00, psi_term=4.2167e+00, obj=206109111.981833, solved_in=0.007s
# step 70: psi_curr=6.2235e+00, min_psi_pred=6.2555e+00, psi_term=4.2845e+00, obj=204305158.241482, solved_in=0.008s
# step 71: psi_curr=6.2555e+00, min_psi_pred=6.2873e+00, psi_term=4.3518e+00, obj=202541877.474830, solved_in=0.008s
# step 72: psi_curr=6.2873e+00, min_psi_pred=6.3191e+00, psi_term=4.4186e+00, obj=200817813.898937, solved_in=0.008s
# step 73: psi_curr=6.3191e+00, min_psi_pred=6.3509e+00, psi_term=4.4851e+00, obj=199131553.356030, solved_in=0.007s
# step 74: psi_curr=6.3509e+00, min_psi_pred=6.3826e+00, psi_term=4.5511e+00, obj=197481721.227652, solved_in=0.007s
# step 75: psi_curr=6.3826e+00, min_psi_pred=6.4143e+00, psi_term=4.6167e+00, obj=195866980.521402, solved_in=0.007s
# step 76: psi_curr=6.4143e+00, min_psi_pred=6.4460e+00, psi_term=4.6820e+00, obj=194286030.117127, solved_in=0.007s
# step 77: psi_curr=6.4460e+00, min_psi_pred=6.4777e+00, psi_term=4.7469e+00, obj=192737603.160346, solved_in=0.009s
# step 78: psi_curr=6.4777e+00, min_psi_pred=6.5093e+00, psi_term=4.8115e+00, obj=191220465.591756, solved_in=0.008s
# step 79: psi_curr=6.5093e+00, min_psi_pred=6.5410e+00, psi_term=4.8759e+00, obj=189733414.802337, solved_in=0.008s
# step 80: psi_curr=6.5410e+00, min_psi_pred=6.5726e+00, psi_term=4.9399e+00, obj=188275278.404536, solved_in=0.008s
# step 81: psi_curr=6.5726e+00, min_psi_pred=6.6043e+00, psi_term=5.0037e+00, obj=186844913.110576, solved_in=0.007s
# step 82: psi_curr=6.6043e+00, min_psi_pred=6.6360e+00, psi_term=5.0672e+00, obj=185441203.709527, solved_in=0.008s
# step 83: psi_curr=6.6360e+00, min_psi_pred=6.6678e+00, psi_term=5.1305e+00, obj=184063062.135546, solved_in=0.008s
# step 84: psi_curr=6.6678e+00, min_psi_pred=6.6995e+00, psi_term=5.1936e+00, obj=182709426.619963, solved_in=0.008s
# step 85: psi_curr=6.6995e+00, min_psi_pred=6.7313e+00, psi_term=5.2565e+00, obj=181379260.920588, solved_in=0.007s
# step 86: psi_curr=6.7313e+00, min_psi_pred=6.7632e+00, psi_term=5.3192e+00, obj=180071553.621912, solved_in=0.007s
# step 87: psi_curr=6.7632e+00, min_psi_pred=6.7951e+00, psi_term=5.3818e+00, obj=178785317.500370, solved_in=0.007s
# step 88: psi_curr=6.7951e+00, min_psi_pred=6.8271e+00, psi_term=5.4442e+00, obj=177519588.949133, solved_in=0.006s
# step 89: psi_curr=6.8271e+00, min_psi_pred=6.8592e+00, psi_term=5.5065e+00, obj=176273427.457307, solved_in=0.007s
# step 90: psi_curr=6.8592e+00, min_psi_pred=6.8914e+00, psi_term=5.5688e+00, obj=175045915.138691, solved_in=0.008s
# step 91: psi_curr=6.8914e+00, min_psi_pred=6.9237e+00, psi_term=5.6309e+00, obj=173836156.305599, solved_in=0.007s
# step 92: psi_curr=6.9237e+00, min_psi_pred=6.9560e+00, psi_term=5.6929e+00, obj=172643277.083469, solved_in=0.007s
# step 93: psi_curr=6.9560e+00, min_psi_pred=6.9885e+00, psi_term=5.7549e+00, obj=171466425.062253, solved_in=0.008s
# step 94: psi_curr=6.9885e+00, min_psi_pred=7.0212e+00, psi_term=5.8168e+00, obj=170304768.980906, solved_in=0.007s
# step 95: psi_curr=7.0212e+00, min_psi_pred=7.0539e+00, psi_term=5.8787e+00, obj=169157498.441410, solved_in=0.007s
# step 96: psi_curr=7.0539e+00, min_psi_pred=7.0868e+00, psi_term=5.9406e+00, obj=168023823.649070, solved_in=0.007s
# step 97: psi_curr=7.0868e+00, min_psi_pred=7.1198e+00, psi_term=6.0025e+00, obj=166902975.175987, solved_in=0.008s
# step 98: psi_curr=7.1198e+00, min_psi_pred=7.1530e+00, psi_term=6.0643e+00, obj=165794203.744846, solved_in=0.007s
# step 99: psi_curr=7.1530e+00, min_psi_pred=7.1864e+00, psi_term=6.1262e+00, obj=164696780.030269, solved_in=0.007s
# step 100: psi_curr=7.1864e+00, min_psi_pred=7.2199e+00, psi_term=6.1881e+00, obj=163609994.475276, solved_in=0.007s
# step 101: psi_curr=7.2199e+00, min_psi_pred=7.2537e+00, psi_term=6.2501e+00, obj=162533157.120455, solved_in=0.007s
# step 102: psi_curr=7.2537e+00, min_psi_pred=7.2876e+00, psi_term=6.3120e+00, obj=161465597.443707, solved_in=0.008s
# step 103: psi_curr=7.2876e+00, min_psi_pred=7.3217e+00, psi_term=6.3741e+00, obj=160406664.208477, solved_in=0.008s
# step 104: psi_curr=7.3217e+00, min_psi_pred=7.3560e+00, psi_term=6.4362e+00, obj=159355725.318639, solved_in=0.009s
# step 105: psi_curr=7.3560e+00, min_psi_pred=7.3906e+00, psi_term=6.4983e+00, obj=158312167.678270, solved_in=0.008s
# step 106: psi_curr=7.3906e+00, min_psi_pred=7.4253e+00, psi_term=6.5606e+00, obj=157275397.054774, solved_in=0.007s
# step 107: psi_curr=7.4253e+00, min_psi_pred=7.4603e+00, psi_term=6.6229e+00, obj=156244837.943791, solved_in=0.007s
# step 108: psi_curr=7.4603e+00, min_psi_pred=7.4955e+00, psi_term=6.6853e+00, obj=155219933.434679, solved_in=0.007s
# step 109: psi_curr=7.4955e+00, min_psi_pred=7.5310e+00, psi_term=6.7478e+00, obj=154200145.075224, solved_in=0.007s
# step 110: psi_curr=7.5310e+00, min_psi_pred=7.5667e+00, psi_term=6.8103e+00, obj=153184952.734600, solved_in=0.007s
# step 111: psi_curr=7.5667e+00, min_psi_pred=7.6027e+00, psi_term=6.8730e+00, obj=152173854.463522, solved_in=0.007s
# step 112: psi_curr=7.6027e+00, min_psi_pred=7.6389e+00, psi_term=6.9358e+00, obj=151166366.350702, solved_in=0.007s
# step 113: psi_curr=7.6389e+00, min_psi_pred=7.6754e+00, psi_term=6.9987e+00, obj=150162022.374903, solved_in=0.008s
# step 114: psi_curr=7.6754e+00, min_psi_pred=7.7122e+00, psi_term=7.0617e+00, obj=149160374.251835, solved_in=0.007s
# step 115: psi_curr=7.7122e+00, min_psi_pred=7.7493e+00, psi_term=7.1248e+00, obj=148160991.275344, solved_in=0.007s
# step 116: psi_curr=7.7493e+00, min_psi_pred=7.7867e+00, psi_term=7.1880e+00, obj=147163460.152384, solved_in=0.007s
# step 117: psi_curr=7.7867e+00, min_psi_pred=7.8243e+00, psi_term=7.2513e+00, obj=146167384.831344, solved_in=0.007s
# step 118: psi_curr=7.8243e+00, min_psi_pred=7.8623e+00, psi_term=7.3148e+00, obj=145172386.323444, solved_in=0.008s
# step 119: psi_curr=7.8623e+00, min_psi_pred=7.9005e+00, psi_term=7.3783e+00, obj=144178102.516808, solved_in=0.007s
# step 120: psi_curr=7.9005e+00, min_psi_pred=7.9391e+00, psi_term=7.4419e+00, obj=143184187.983200, solved_in=0.007s
# step 121: psi_curr=7.9391e+00, min_psi_pred=7.9780e+00, psi_term=7.5057e+00, obj=142190313.777131, solved_in=0.007s
# step 122: psi_curr=7.9780e+00, min_psi_pred=8.0172e+00, psi_term=7.5695e+00, obj=141196167.227333, solved_in=0.007s
# step 123: psi_curr=8.0172e+00, min_psi_pred=8.0567e+00, psi_term=7.6335e+00, obj=140201451.720613, solved_in=0.007s
# step 124: psi_curr=8.0567e+00, min_psi_pred=8.0965e+00, psi_term=7.6975e+00, obj=139205886.478066, solved_in=0.007s
# step 125: psi_curr=8.0965e+00, min_psi_pred=8.1367e+00, psi_term=7.7617e+00, obj=138209206.323776, solved_in=0.008s
# step 126: psi_curr=8.1367e+00, min_psi_pred=8.1772e+00, psi_term=7.8259e+00, obj=137211161.446104, solved_in=0.007s
# step 127: psi_curr=8.1772e+00, min_psi_pred=8.2180e+00, psi_term=7.8902e+00, obj=136211517.151773, solved_in=0.008s
# step 128: psi_curr=8.2180e+00, min_psi_pred=8.2592e+00, psi_term=7.9546e+00, obj=135210053.612918, solved_in=0.007s
# step 129: psi_curr=8.2592e+00, min_psi_pred=8.3007e+00, psi_term=8.0190e+00, obj=134206565.607365, solved_in=0.007s
# step 130: psi_curr=8.3007e+00, min_psi_pred=8.3426e+00, psi_term=8.0836e+00, obj=133200862.252397, solved_in=0.008s
# step 131: psi_curr=8.3426e+00, min_psi_pred=8.3848e+00, psi_term=8.1481e+00, obj=132192766.732310, solved_in=0.009s
# step 132: psi_curr=8.3848e+00, min_psi_pred=8.4274e+00, psi_term=8.2128e+00, obj=131182116.020057, solved_in=0.009s
# step 133: psi_curr=8.4274e+00, min_psi_pred=8.4703e+00, psi_term=8.2774e+00, obj=130168760.593405, solved_in=0.007s
# step 134: psi_curr=8.4703e+00, min_psi_pred=8.5135e+00, psi_term=8.3422e+00, obj=129152564.145779, solved_in=0.008s
# step 135: psi_curr=8.5135e+00, min_psi_pred=8.5571e+00, psi_term=8.4069e+00, obj=128133403.292389, solved_in=0.007s
# step 136: psi_curr=8.5571e+00, min_psi_pred=8.6011e+00, psi_term=8.4717e+00, obj=127111167.271843, solved_in=0.007s
# step 137: psi_curr=8.6011e+00, min_psi_pred=8.6454e+00, psi_term=8.5365e+00, obj=126085757.643732, solved_in=0.008s
# step 138: psi_curr=8.6454e+00, min_psi_pred=8.6901e+00, psi_term=8.6013e+00, obj=125057087.982552, solved_in=0.008s
# step 139: psi_curr=8.6901e+00, min_psi_pred=8.7351e+00, psi_term=8.6660e+00, obj=124025083.568366, solved_in=0.008s
# step 140: psi_curr=8.7351e+00, min_psi_pred=8.7805e+00, psi_term=8.7308e+00, obj=122989681.077163, solved_in=0.010s
# step 141: psi_curr=8.7805e+00, min_psi_pred=8.8262e+00, psi_term=8.7956e+00, obj=121950828.254352, solved_in=0.008s
# step 142: psi_curr=8.8262e+00, min_psi_pred=8.8723e+00, psi_term=8.8603e+00, obj=120908483.617691, solved_in=0.013s
# step 143: psi_curr=8.8723e+00, min_psi_pred=8.9187e+00, psi_term=8.9249e+00, obj=119862616.128467, solved_in=0.008s
# step 144: psi_curr=8.9187e+00, min_psi_pred=8.9655e+00, psi_term=8.9896e+00, obj=118813204.867017, solved_in=0.008s
# step 145: psi_curr=8.9655e+00, min_psi_pred=9.0127e+00, psi_term=9.0541e+00, obj=117760238.719440, solved_in=0.008s
# step 146: psi_curr=9.0127e+00, min_psi_pred=9.0602e+00, psi_term=9.1186e+00, obj=116703716.055124, solved_in=0.008s
# step 147: psi_curr=9.0602e+00, min_psi_pred=9.1080e+00, psi_term=9.1830e+00, obj=115643644.405659, solved_in=0.007s
# step 148: psi_curr=9.1080e+00, min_psi_pred=9.1562e+00, psi_term=9.2473e+00, obj=114580040.144227, solved_in=0.007s
# step 149: psi_curr=9.1562e+00, min_psi_pred=9.2047e+00, psi_term=9.3115e+00, obj=113512928.165654, solved_in=0.009s
# step 150: psi_curr=9.2047e+00, min_psi_pred=9.2536e+00, psi_term=9.3756e+00, obj=112442341.567485, solved_in=0.008s
# step 151: psi_curr=9.2536e+00, min_psi_pred=9.3028e+00, psi_term=9.4395e+00, obj=111368321.332388, solved_in=0.007s
# step 152: psi_curr=9.3028e+00, min_psi_pred=9.3524e+00, psi_term=9.5033e+00, obj=110290916.012267, solved_in=0.008s
# step 153: psi_curr=9.3524e+00, min_psi_pred=9.4023e+00, psi_term=9.5670e+00, obj=109210181.414349, solved_in=0.008s
# step 154: psi_curr=9.4023e+00, min_psi_pred=9.4526e+00, psi_term=9.6305e+00, obj=108126180.289576, solved_in=0.008s
# step 155: psi_curr=9.4526e+00, min_psi_pred=9.5031e+00, psi_term=9.6938e+00, obj=107038982.023607, solved_in=0.008s
# step 156: psi_curr=9.5031e+00, min_psi_pred=9.5540e+00, psi_term=9.7570e+00, obj=105948662.330658, solved_in=0.007s
# step 157: psi_curr=9.5540e+00, min_psi_pred=9.6053e+00, psi_term=9.8199e+00, obj=104855302.950530, solved_in=0.008s
# step 158: psi_curr=9.6053e+00, min_psi_pred=9.6568e+00, psi_term=9.8827e+00, obj=103758991.351194, solved_in=0.007s
# step 159: psi_curr=9.6568e+00, min_psi_pred=9.7087e+00, psi_term=9.9452e+00, obj=102659820.421058, solved_in=0.008s
# step 160: psi_curr=9.7087e+00, min_psi_pred=9.7609e+00, psi_term=1.0008e+01, obj=101557888.201338, solved_in=0.008s
# step 161: psi_curr=9.7609e+00, min_psi_pred=9.8134e+00, psi_term=1.0070e+01, obj=100453297.573138, solved_in=0.008s
# step 162: psi_curr=9.8134e+00, min_psi_pred=9.8662e+00, psi_term=1.0131e+01, obj=99346155.985563, solved_in=0.009s
# step 163: psi_curr=9.8662e+00, min_psi_pred=9.9194e+00, psi_term=1.0193e+01, obj=98236575.174603, solved_in=0.008s
# step 164: psi_curr=9.9194e+00, min_psi_pred=9.9728e+00, psi_term=1.0254e+01, obj=97124670.888202, solved_in=0.016s
# step 165: psi_curr=9.9728e+00, min_psi_pred=1.0027e+01, psi_term=1.0315e+01, obj=96010562.616312, solved_in=0.011s
# step 166: psi_curr=1.0027e+01, min_psi_pred=1.0081e+01, psi_term=1.0376e+01, obj=94894373.325877, solved_in=0.007s
# step 167: psi_curr=1.0081e+01, min_psi_pred=1.0135e+01, psi_term=1.0436e+01, obj=93776229.200892, solved_in=0.009s
# step 168: psi_curr=1.0135e+01, min_psi_pred=1.0189e+01, psi_term=1.0496e+01, obj=92656259.387648, solved_in=0.007s
# step 169: psi_curr=1.0189e+01, min_psi_pred=1.0244e+01, psi_term=1.0556e+01, obj=91534595.745259, solved_in=0.008s
# step 170: psi_curr=1.0244e+01, min_psi_pred=1.0300e+01, psi_term=1.0615e+01, obj=90411372.601603, solved_in=0.008s
# step 171: psi_curr=1.0300e+01, min_psi_pred=1.0355e+01, psi_term=1.0675e+01, obj=89286726.514707, solved_in=0.007s
# step 172: psi_curr=1.0355e+01, min_psi_pred=1.0411e+01, psi_term=1.0733e+01, obj=88160796.039712, solved_in=0.007s
# step 173: psi_curr=1.0411e+01, min_psi_pred=1.0467e+01, psi_term=1.0792e+01, obj=87033721.501427, solved_in=0.008s
# step 174: psi_curr=1.0467e+01, min_psi_pred=1.0523e+01, psi_term=1.0850e+01, obj=85905644.772568, solved_in=0.007s
# step 175: psi_curr=1.0523e+01, min_psi_pred=1.0579e+01, psi_term=1.0907e+01, obj=84776709.057676, solved_in=0.007s
# step 176: psi_curr=1.0579e+01, min_psi_pred=1.0636e+01, psi_term=1.0964e+01, obj=83647058.682791, solved_in=0.007s
# step 177: psi_curr=1.0636e+01, min_psi_pred=1.0693e+01, psi_term=1.1021e+01, obj=82516838.890851, solved_in=0.007s
# step 178: psi_curr=1.0693e+01, min_psi_pred=1.0750e+01, psi_term=1.1077e+01, obj=81386195.642894, solved_in=0.007s
# step 179: psi_curr=1.0750e+01, min_psi_pred=1.0808e+01, psi_term=1.1133e+01, obj=80255275.424961, solved_in=0.007s
# step 180: psi_curr=1.0808e+01, min_psi_pred=1.0866e+01, psi_term=1.1189e+01, obj=79124225.060799, solved_in=0.007s
# step 181: psi_curr=1.0866e+01, min_psi_pred=1.0923e+01, psi_term=1.1244e+01, obj=77993191.530262, solved_in=0.007s
# step 182: psi_curr=1.0923e+01, min_psi_pred=1.0982e+01, psi_term=1.1298e+01, obj=76862321.793399, solved_in=0.007s
# step 183: psi_curr=1.0982e+01, min_psi_pred=1.1040e+01, psi_term=1.1353e+01, obj=75731762.620212, solved_in=0.008s
# step 184: psi_curr=1.1040e+01, min_psi_pred=1.1099e+01, psi_term=1.1406e+01, obj=74601660.425991, solved_in=0.007s
# step 185: psi_curr=1.1099e+01, min_psi_pred=1.1157e+01, psi_term=1.1459e+01, obj=73472161.112197, solved_in=0.007s
# step 186: psi_curr=1.1157e+01, min_psi_pred=1.1216e+01, psi_term=1.1512e+01, obj=72343409.912797, solved_in=0.007s
# step 187: psi_curr=1.1216e+01, min_psi_pred=1.1276e+01, psi_term=1.1564e+01, obj=71215551.245973, solved_in=0.007s
# step 188: psi_curr=1.1276e+01, min_psi_pred=1.1335e+01, psi_term=1.1616e+01, obj=70088728.571119, solved_in=0.007s
# step 189: psi_curr=1.1335e+01, min_psi_pred=1.1394e+01, psi_term=1.1667e+01, obj=68963084.250995, solved_in=0.007s
# step 190: psi_curr=1.1394e+01, min_psi_pred=1.1454e+01, psi_term=1.1718e+01, obj=67838759.418925, solved_in=0.008s
# step 191: psi_curr=1.1454e+01, min_psi_pred=1.1514e+01, psi_term=1.1768e+01, obj=66715893.850943, solved_in=0.007s
# step 192: psi_curr=1.1514e+01, min_psi_pred=1.1574e+01, psi_term=1.1818e+01, obj=65594625.842660, solved_in=0.007s
# step 193: psi_curr=1.1574e+01, min_psi_pred=1.1634e+01, psi_term=1.1867e+01, obj=64475092.090751, solved_in=0.007s
# step 194: psi_curr=1.1634e+01, min_psi_pred=1.1695e+01, psi_term=1.1915e+01, obj=63357427.578871, solved_in=0.007s
# step 195: psi_curr=1.1695e+01, min_psi_pred=1.1755e+01, psi_term=1.1963e+01, obj=62241765.467769, solved_in=0.007s
# step 196: psi_curr=1.1755e+01, min_psi_pred=1.1816e+01, psi_term=1.2011e+01, obj=61128236.989403, solved_in=0.007s
# step 197: psi_curr=1.1816e+01, min_psi_pred=1.1877e+01, psi_term=1.2058e+01, obj=60016971.344825, solved_in=0.008s
# step 198: psi_curr=1.1877e+01, min_psi_pred=1.1938e+01, psi_term=1.2104e+01, obj=58908095.605512, solved_in=0.007s
# step 199: psi_curr=1.1938e+01, min_psi_pred=1.1999e+01, psi_term=1.2150e+01, obj=57801734.617919, solved_in=0.006s
# step 200: psi_curr=1.1999e+01, min_psi_pred=1.2061e+01, psi_term=1.2195e+01, obj=56698010.910853, solved_in=0.007s
# step 201: psi_curr=1.2061e+01, min_psi_pred=1.2122e+01, psi_term=1.2240e+01, obj=55597044.605327, solved_in=0.007s
# step 202: psi_curr=1.2122e+01, min_psi_pred=1.2183e+01, psi_term=1.2284e+01, obj=54498953.326513, solved_in=0.008s
# step 203: psi_curr=1.2183e+01, min_psi_pred=1.2245e+01, psi_term=1.2327e+01, obj=53403852.117251, solved_in=0.007s
# step 204: psi_curr=1.2245e+01, min_psi_pred=1.2307e+01, psi_term=1.2370e+01, obj=52311853.352687, solved_in=0.007s
# step 205: psi_curr=1.2307e+01, min_psi_pred=1.2369e+01, psi_term=1.2412e+01, obj=51223066.655391, solved_in=0.007s
# step 206: psi_curr=1.2369e+01, min_psi_pred=1.2431e+01, psi_term=1.2454e+01, obj=50137598.810337, solved_in=0.007s
# step 207: psi_curr=1.2431e+01, min_psi_pred=1.2493e+01, psi_term=1.2495e+01, obj=49055553.678949, solved_in=0.008s
# step 208: psi_curr=1.2493e+01, min_psi_pred=1.2555e+01, psi_term=1.2535e+01, obj=47977032.111439, solved_in=0.008s
# step 209: psi_curr=1.2555e+01, min_psi_pred=1.2617e+01, psi_term=1.2575e+01, obj=46902131.856379, solved_in=0.008s
# step 210: psi_curr=1.2617e+01, min_psi_pred=1.2679e+01, psi_term=1.2615e+01, obj=45830947.466480, solved_in=0.008s
# step 211: psi_curr=1.2679e+01, min_psi_pred=1.2742e+01, psi_term=1.2653e+01, obj=44763570.199238, solved_in=0.007s
# step 212: psi_curr=1.2742e+01, min_psi_pred=1.2804e+01, psi_term=1.2691e+01, obj=43700087.911029, solved_in=0.007s
# step 213: psi_curr=1.2804e+01, min_psi_pred=1.2867e+01, psi_term=1.2728e+01, obj=42640584.942899, solved_in=0.007s
# step 214: psi_curr=1.2867e+01, min_psi_pred=1.2929e+01, psi_term=1.2765e+01, obj=41585141.996141, solved_in=0.007s
# step 215: psi_curr=1.2929e+01, min_psi_pred=1.2992e+01, psi_term=1.2801e+01, obj=40533835.995301, solved_in=0.007s
# step 216: psi_curr=1.2992e+01, min_psi_pred=1.3055e+01, psi_term=1.2837e+01, obj=39486739.935966, solved_in=0.007s
# step 217: psi_curr=1.3055e+01, min_psi_pred=1.3117e+01, psi_term=1.2872e+01, obj=38443922.714155, solved_in=0.008s
# step 218: psi_curr=1.3117e+01, min_psi_pred=1.3180e+01, psi_term=1.2906e+01, obj=37405448.933647, solved_in=0.007s
# step 219: psi_curr=1.3180e+01, min_psi_pred=1.3243e+01, psi_term=1.2939e+01, obj=36371378.686810, solved_in=0.007s
# step 220: psi_curr=1.3243e+01, min_psi_pred=1.3306e+01, psi_term=1.2972e+01, obj=35341767.303792, solved_in=0.007s
# step 221: psi_curr=1.3306e+01, min_psi_pred=1.3369e+01, psi_term=1.3005e+01, obj=34316665.063870, solved_in=0.007s
# step 222: psi_curr=1.3369e+01, min_psi_pred=1.3432e+01, psi_term=1.3036e+01, obj=33296116.861607, solved_in=0.007s
# step 223: psi_curr=1.3432e+01, min_psi_pred=1.3495e+01, psi_term=1.3067e+01, obj=32280161.818958, solved_in=0.007s
# step 224: psi_curr=1.3495e+01, min_psi_pred=1.3558e+01, psi_term=1.3098e+01, obj=31268832.832745, solved_in=0.007s
# step 225: psi_curr=1.3558e+01, min_psi_pred=1.3621e+01, psi_term=1.3128e+01, obj=30262156.044657, solved_in=0.008s
# step 226: psi_curr=1.3621e+01, min_psi_pred=1.3684e+01, psi_term=1.3157e+01, obj=29260150.218252, solved_in=0.008s
# step 227: psi_curr=1.3684e+01, min_psi_pred=1.3747e+01, psi_term=1.3185e+01, obj=28262826.004098, solved_in=0.007s
# step 228: psi_curr=1.3747e+01, min_psi_pred=1.3810e+01, psi_term=1.3213e+01, obj=27270185.069970, solved_in=0.007s
# step 229: psi_curr=1.3810e+01, min_psi_pred=1.3873e+01, psi_term=1.3240e+01, obj=26282219.067928, solved_in=0.007s
# step 230: psi_curr=1.3873e+01, min_psi_pred=1.3937e+01, psi_term=1.3266e+01, obj=25298908.403514, solved_in=0.008s
# step 231: psi_curr=1.3937e+01, min_psi_pred=1.4000e+01, psi_term=1.3292e+01, obj=24320220.764311, solved_in=0.007s
# step 232: psi_curr=1.4000e+01, min_psi_pred=1.4063e+01, psi_term=1.3317e+01, obj=23346109.354885, solved_in=0.007s
# step 233: psi_curr=1.4063e+01, min_psi_pred=1.4126e+01, psi_term=1.3342e+01, obj=22376510.772468, solved_in=0.007s
# step 234: psi_curr=1.4126e+01, min_psi_pred=1.4189e+01, psi_term=1.3366e+01, obj=21411342.441819, solved_in=0.007s
# step 235: psi_curr=1.4189e+01, min_psi_pred=1.4252e+01, psi_term=1.3389e+01, obj=20450499.507926, solved_in=0.007s
# step 236: psi_curr=1.4252e+01, min_psi_pred=1.4315e+01, psi_term=1.3411e+01, obj=19493851.060844, solved_in=0.007s
# step 237: psi_curr=1.4315e+01, min_psi_pred=1.4378e+01, psi_term=1.3433e+01, obj=18541235.537404, solved_in=0.007s
# step 238: psi_curr=1.4378e+01, min_psi_pred=1.4442e+01, psi_term=1.3454e+01, obj=17592455.109944, solved_in=0.009s
# step 239: psi_curr=1.4442e+01, min_psi_pred=1.4505e+01, psi_term=1.3474e+01, obj=16647268.833995, solved_in=0.008s
# step 240: psi_curr=1.4505e+01, min_psi_pred=1.4568e+01, psi_term=1.3494e+01, obj=15705384.290317, solved_in=0.008s
# step 241: psi_curr=1.4568e+01, min_psi_pred=1.4631e+01, psi_term=1.3513e+01, obj=14766447.434482, solved_in=0.007s
# step 242: psi_curr=1.4631e+01, min_psi_pred=1.4694e+01, psi_term=1.3531e+01, obj=13830030.389437, solved_in=0.007s
# step 243: psi_curr=1.4694e+01, min_psi_pred=1.4757e+01, psi_term=1.3548e+01, obj=12895617.049682, solved_in=0.007s
# step 244: psi_curr=1.4757e+01, min_psi_pred=1.4820e+01, psi_term=1.3565e+01, obj=11962586.757549, solved_in=0.007s
# step 245: psi_curr=1.4820e+01, min_psi_pred=1.4884e+01, psi_term=1.3581e+01, obj=11030197.290842, solved_in=0.007s
# step 246: psi_curr=1.4884e+01, min_psi_pred=1.4947e+01, psi_term=1.3595e+01, obj=10097570.708523, solved_in=0.009s
# step 247: psi_curr=1.4947e+01, min_psi_pred=1.5010e+01, psi_term=1.3609e+01, obj=9163690.955047, solved_in=0.013s
# step 248: psi_curr=1.5010e+01, min_psi_pred=1.5073e+01, psi_term=1.3622e+01, obj=8227434.629925, solved_in=0.013s
# step 249: psi_curr=1.5073e+01, min_psi_pred=1.5137e+01, psi_term=1.3633e+01, obj=7287686.174554, solved_in=0.011s
# Reached target at step 249
# Result: reached steps: 251
#
# Trial 1, initial = [1.35       1.6        3.14159265 1.        ]
# step 0: psi_curr=1.1485e+01, min_psi_pred=1.1473e+01, psi_term=7.4107e+00, obj=6771487159.099397, solved_in=0.074s
# step 1: psi_curr=1.1489e+01, min_psi_pred=1.1461e+01, psi_term=7.0185e+00, obj=6019568842.638263, solved_in=0.128s
# step 2: psi_curr=1.1519e+01, min_psi_pred=1.1556e+01, psi_term=8.7131e+00, obj=2146484306.268102, solved_in=0.014s
# step 3: psi_curr=1.1556e+01, min_psi_pred=1.1595e+01, psi_term=8.7921e+00, obj=1234320459.181484, solved_in=0.010s
# step 4: psi_curr=1.1595e+01, min_psi_pred=1.1624e+01, psi_term=8.8606e+00, obj=733640327.544877, solved_in=0.008s
# step 5: psi_curr=1.1624e+01, min_psi_pred=1.1646e+01, psi_term=8.9210e+00, obj=549571520.604340, solved_in=0.007s
# step 6: psi_curr=1.1646e+01, min_psi_pred=1.1663e+01, psi_term=8.9748e+00, obj=465167008.988860, solved_in=0.008s
# step 7: psi_curr=1.1663e+01, min_psi_pred=1.1678e+01, psi_term=9.0232e+00, obj=415142846.768201, solved_in=0.008s
# step 8: psi_curr=1.1678e+01, min_psi_pred=1.1692e+01, psi_term=9.0670e+00, obj=380032110.293835, solved_in=0.008s
# step 9: psi_curr=1.1692e+01, min_psi_pred=1.1704e+01, psi_term=9.1069e+00, obj=352981120.860473, solved_in=0.008s
# step 10: psi_curr=1.1704e+01, min_psi_pred=1.1715e+01, psi_term=9.1435e+00, obj=331051515.033930, solved_in=0.008s
# step 11: psi_curr=1.1715e+01, min_psi_pred=1.1726e+01, psi_term=9.1770e+00, obj=312723724.193771, solved_in=0.007s
# step 12: psi_curr=1.1726e+01, min_psi_pred=1.1736e+01, psi_term=9.2080e+00, obj=297087663.290960, solved_in=0.009s
# step 13: psi_curr=1.1736e+01, min_psi_pred=1.1745e+01, psi_term=9.2366e+00, obj=283541799.342390, solved_in=0.007s
# step 14: psi_curr=1.1745e+01, min_psi_pred=1.1753e+01, psi_term=9.2631e+00, obj=271662812.892165, solved_in=0.007s
# step 15: psi_curr=1.1753e+01, min_psi_pred=1.1761e+01, psi_term=9.2877e+00, obj=261140223.374750, solved_in=0.007s
# step 16: psi_curr=1.1761e+01, min_psi_pred=1.1769e+01, psi_term=9.3106e+00, obj=251739487.195079, solved_in=0.007s
# step 17: psi_curr=1.1769e+01, min_psi_pred=1.1776e+01, psi_term=9.3319e+00, obj=243279341.193242, solved_in=0.007s
# step 18: psi_curr=1.1776e+01, min_psi_pred=1.1783e+01, psi_term=9.3518e+00, obj=235617068.012352, solved_in=0.006s
# step 19: psi_curr=1.1783e+01, min_psi_pred=1.1789e+01, psi_term=9.3704e+00, obj=228638515.544567, solved_in=0.008s
# step 20: psi_curr=1.1789e+01, min_psi_pred=1.1795e+01, psi_term=9.3877e+00, obj=222251126.303792, solved_in=0.007s
# step 21: psi_curr=1.1795e+01, min_psi_pred=1.1801e+01, psi_term=9.4039e+00, obj=216378948.123507, solved_in=0.007s
# step 22: psi_curr=1.1801e+01, min_psi_pred=1.1806e+01, psi_term=9.4191e+00, obj=210958988.839120, solved_in=0.007s
# step 23: psi_curr=1.1806e+01, min_psi_pred=1.1811e+01, psi_term=9.4332e+00, obj=205938505.208655, solved_in=0.007s
# step 24: psi_curr=1.1811e+01, min_psi_pred=1.1816e+01, psi_term=9.4465e+00, obj=201272954.873724, solved_in=0.007s
# step 25: psi_curr=1.1816e+01, min_psi_pred=1.1821e+01, psi_term=9.4588e+00, obj=196924427.487007, solved_in=0.007s
# step 26: psi_curr=1.1821e+01, min_psi_pred=1.1825e+01, psi_term=9.4703e+00, obj=192860427.732434, solved_in=0.006s
# step 27: psi_curr=1.1825e+01, min_psi_pred=1.1829e+01, psi_term=9.4811e+00, obj=189052920.523337, solved_in=0.008s
# step 28: psi_curr=1.1829e+01, min_psi_pred=1.1833e+01, psi_term=9.4911e+00, obj=185477574.102050, solved_in=0.007s
# step 29: psi_curr=1.1833e+01, min_psi_pred=1.1836e+01, psi_term=9.5004e+00, obj=182113154.308471, solved_in=0.007s
# step 30: psi_curr=1.1836e+01, min_psi_pred=1.1840e+01, psi_term=9.5091e+00, obj=178941035.583583, solved_in=0.007s
# step 31: psi_curr=1.1840e+01, min_psi_pred=1.1842e+01, psi_term=9.5172e+00, obj=175944803.023755, solved_in=0.007s
# step 32: psi_curr=1.1843e+01, min_psi_pred=1.1844e+01, psi_term=9.5246e+00, obj=173109926.111635, solved_in=0.006s
# step 33: psi_curr=1.1846e+01, min_psi_pred=1.1846e+01, psi_term=9.5315e+00, obj=170423489.356663, solved_in=0.007s
# step 34: psi_curr=1.1849e+01, min_psi_pred=1.1848e+01, psi_term=9.5379e+00, obj=167873968.481287, solved_in=0.007s
# step 35: psi_curr=1.1851e+01, min_psi_pred=1.1850e+01, psi_term=9.5437e+00, obj=165451043.329087, solved_in=0.007s
# step 36: psi_curr=1.1854e+01, min_psi_pred=1.1852e+01, psi_term=9.5491e+00, obj=163145440.586272, solved_in=0.008s
# step 37: psi_curr=1.1856e+01, min_psi_pred=1.1854e+01, psi_term=9.5540e+00, obj=160948800.865051, solved_in=0.008s
# step 38: psi_curr=1.1858e+01, min_psi_pred=1.1855e+01, psi_term=9.5584e+00, obj=158853565.815821, solved_in=0.007s
# step 39: psi_curr=1.1860e+01, min_psi_pred=1.1856e+01, psi_term=9.5625e+00, obj=156852881.800274, solved_in=0.008s
# step 40: psi_curr=1.1862e+01, min_psi_pred=1.1857e+01, psi_term=9.5661e+00, obj=154940517.332099, solved_in=0.008s
# step 41: psi_curr=1.1864e+01, min_psi_pred=1.1858e+01, psi_term=9.5693e+00, obj=153110792.021521, solved_in=0.007s
# step 42: psi_curr=1.1865e+01, min_psi_pred=1.1859e+01, psi_term=9.5721e+00, obj=151358515.178600, solved_in=0.007s
# step 43: psi_curr=1.1867e+01, min_psi_pred=1.1860e+01, psi_term=9.5746e+00, obj=149678932.563179, solved_in=0.007s
# step 44: psi_curr=1.1868e+01, min_psi_pred=1.1861e+01, psi_term=9.5767e+00, obj=148067680.035956, solved_in=0.008s
# step 45: psi_curr=1.1869e+01, min_psi_pred=1.1861e+01, psi_term=9.5785e+00, obj=146520743.079641, solved_in=0.008s
# step 46: psi_curr=1.1870e+01, min_psi_pred=1.1862e+01, psi_term=9.5800e+00, obj=145034421.333761, solved_in=0.008s
# step 47: psi_curr=1.1871e+01, min_psi_pred=1.1862e+01, psi_term=9.5811e+00, obj=143605297.419748, solved_in=0.008s
# step 48: psi_curr=1.1872e+01, min_psi_pred=1.1862e+01, psi_term=9.5820e+00, obj=142230209.477453, solved_in=0.007s
# step 49: psi_curr=1.1872e+01, min_psi_pred=1.1863e+01, psi_term=9.5826e+00, obj=140906226.870577, solved_in=0.007s
# step 50: psi_curr=1.1873e+01, min_psi_pred=1.1863e+01, psi_term=9.5829e+00, obj=139630628.668752, solved_in=0.007s
# step 51: psi_curr=1.1873e+01, min_psi_pred=1.1863e+01, psi_term=9.5829e+00, obj=138400884.523737, solved_in=0.007s
# step 52: psi_curr=1.1874e+01, min_psi_pred=1.1862e+01, psi_term=9.5827e+00, obj=137214637.635860, solved_in=0.007s
# step 53: psi_curr=1.1874e+01, min_psi_pred=1.1862e+01, psi_term=9.5822e+00, obj=136069689.546372, solved_in=0.008s
# step 54: psi_curr=1.1874e+01, min_psi_pred=1.1862e+01, psi_term=9.5816e+00, obj=134963986.529335, solved_in=0.008s
# step 55: psi_curr=1.1874e+01, min_psi_pred=1.1862e+01, psi_term=9.5806e+00, obj=133895607.388381, solved_in=0.008s
# step 56: psi_curr=1.1874e+01, min_psi_pred=1.1861e+01, psi_term=9.5795e+00, obj=132862752.490559, solved_in=0.008s
# step 57: psi_curr=1.1874e+01, min_psi_pred=1.1861e+01, psi_term=9.5782e+00, obj=131863733.892102, solved_in=0.009s
# step 58: psi_curr=1.1874e+01, min_psi_pred=1.1860e+01, psi_term=9.5766e+00, obj=130896966.430267, solved_in=0.008s
# step 59: psi_curr=1.1873e+01, min_psi_pred=1.1859e+01, psi_term=9.5749e+00, obj=129960959.671810, solved_in=0.009s
# step 60: psi_curr=1.1873e+01, min_psi_pred=1.1859e+01, psi_term=9.5730e+00, obj=129054310.622695, solved_in=0.007s
# step 61: psi_curr=1.1873e+01, min_psi_pred=1.1858e+01, psi_term=9.5709e+00, obj=128175697.115678, solved_in=0.008s
# step 62: psi_curr=1.1872e+01, min_psi_pred=1.1857e+01, psi_term=9.5687e+00, obj=127323871.802749, solved_in=0.006s
# step 63: psi_curr=1.1872e+01, min_psi_pred=1.1856e+01, psi_term=9.5663e+00, obj=126497656.688318, solved_in=0.007s
# step 64: psi_curr=1.1871e+01, min_psi_pred=1.1855e+01, psi_term=9.5637e+00, obj=125695938.146743, solved_in=0.007s
# step 65: psi_curr=1.1870e+01, min_psi_pred=1.1854e+01, psi_term=9.5610e+00, obj=124917662.374471, solved_in=0.007s
# step 66: psi_curr=1.1869e+01, min_psi_pred=1.1853e+01, psi_term=9.5581e+00, obj=124161831.232822, solved_in=0.007s
# step 67: psi_curr=1.1868e+01, min_psi_pred=1.1852e+01, psi_term=9.5551e+00, obj=123427498.442543, solved_in=0.007s
# step 68: psi_curr=1.1868e+01, min_psi_pred=1.1851e+01, psi_term=9.5520e+00, obj=122713766.095584, solved_in=0.007s
# step 69: psi_curr=1.1867e+01, min_psi_pred=1.1849e+01, psi_term=9.5488e+00, obj=122019781.453451, solved_in=0.007s
# step 70: psi_curr=1.1866e+01, min_psi_pred=1.1848e+01, psi_term=9.5454e+00, obj=121344734.004798, solved_in=0.007s
# step 71: psi_curr=1.1864e+01, min_psi_pred=1.1847e+01, psi_term=9.5419e+00, obj=120687852.757930, solved_in=0.007s
# step 72: psi_curr=1.1863e+01, min_psi_pred=1.1845e+01, psi_term=9.5383e+00, obj=120048403.746428, solved_in=0.009s
# step 73: psi_curr=1.1862e+01, min_psi_pred=1.1844e+01, psi_term=9.5347e+00, obj=119425687.728437, solved_in=0.009s
# step 74: psi_curr=1.1861e+01, min_psi_pred=1.1843e+01, psi_term=9.5309e+00, obj=118819038.062156, solved_in=0.011s
# step 75: psi_curr=1.1860e+01, min_psi_pred=1.1841e+01, psi_term=9.5270e+00, obj=118227818.741846, solved_in=0.007s
# step 76: psi_curr=1.1858e+01, min_psi_pred=1.1840e+01, psi_term=9.5231e+00, obj=117651422.580286, solved_in=0.007s
# step 77: psi_curr=1.1857e+01, min_psi_pred=1.1838e+01, psi_term=9.5191e+00, obj=117089269.524969, solved_in=0.007s
# step 78: psi_curr=1.1856e+01, min_psi_pred=1.1837e+01, psi_term=9.5150e+00, obj=116540805.096600, solved_in=0.008s
# step 79: psi_curr=1.1854e+01, min_psi_pred=1.1835e+01, psi_term=9.5108e+00, obj=116005498.939578, solved_in=0.010s
# step 80: psi_curr=1.1853e+01, min_psi_pred=1.1833e+01, psi_term=9.5066e+00, obj=115482843.475096, solved_in=0.008s
# step 81: psi_curr=1.1851e+01, min_psi_pred=1.1832e+01, psi_term=9.5023e+00, obj=114972352.648416, solved_in=0.008s
# step 82: psi_curr=1.1850e+01, min_psi_pred=1.1830e+01, psi_term=9.4980e+00, obj=114473560.762643, solved_in=0.007s
# step 83: psi_curr=1.1848e+01, min_psi_pred=1.1828e+01, psi_term=9.4936e+00, obj=113986021.392043, solved_in=0.008s
# step 84: psi_curr=1.1846e+01, min_psi_pred=1.1827e+01, psi_term=9.4892e+00, obj=113509306.368571, solved_in=0.007s
# step 85: psi_curr=1.1845e+01, min_psi_pred=1.1825e+01, psi_term=9.4847e+00, obj=113043004.835852, solved_in=0.007s
# step 86: psi_curr=1.1843e+01, min_psi_pred=1.1823e+01, psi_term=9.4802e+00, obj=112586722.365379, solved_in=0.008s
# step 87: psi_curr=1.1841e+01, min_psi_pred=1.1821e+01, psi_term=9.4756e+00, obj=112140080.130137, solved_in=0.007s
# step 88: psi_curr=1.1840e+01, min_psi_pred=1.1820e+01, psi_term=9.4711e+00, obj=111702714.131284, solved_in=0.007s
# step 89: psi_curr=1.1838e+01, min_psi_pred=1.1818e+01, psi_term=9.4665e+00, obj=111274274.473914, solved_in=0.007s
# step 90: psi_curr=1.1836e+01, min_psi_pred=1.1816e+01, psi_term=9.4619e+00, obj=110854424.688231, solved_in=0.007s
# step 91: psi_curr=1.1834e+01, min_psi_pred=1.1814e+01, psi_term=9.4572e+00, obj=110442841.092797, solved_in=0.007s
# step 92: psi_curr=1.1833e+01, min_psi_pred=1.1812e+01, psi_term=9.4526e+00, obj=110039212.196797, solved_in=0.007s
# step 93: psi_curr=1.1831e+01, min_psi_pred=1.1810e+01, psi_term=9.4479e+00, obj=109643238.138487, solved_in=0.007s
# step 94: psi_curr=1.1829e+01, min_psi_pred=1.1809e+01, psi_term=9.4433e+00, obj=109254630.157271, solved_in=0.007s
# step 95: psi_curr=1.1827e+01, min_psi_pred=1.1807e+01, psi_term=9.4386e+00, obj=108873110.096991, solved_in=0.007s
# step 96: psi_curr=1.1825e+01, min_psi_pred=1.1805e+01, psi_term=9.4340e+00, obj=108498409.938283, solved_in=0.008s
# step 97: psi_curr=1.1824e+01, min_psi_pred=1.1803e+01, psi_term=9.4293e+00, obj=108130271.357957, solved_in=0.007s
# step 98: psi_curr=1.1822e+01, min_psi_pred=1.1801e+01, psi_term=9.4247e+00, obj=107768445.313567, solved_in=0.007s
# step 99: psi_curr=1.1820e+01, min_psi_pred=1.1799e+01, psi_term=9.4200e+00, obj=107412691.651430, solved_in=0.007s
# step 100: psi_curr=1.1818e+01, min_psi_pred=1.1798e+01, psi_term=9.4154e+00, obj=107062778.736545, solved_in=0.007s
# step 101: psi_curr=1.1816e+01, min_psi_pred=1.1796e+01, psi_term=9.4108e+00, obj=106718483.102930, solved_in=0.007s
# step 102: psi_curr=1.1814e+01, min_psi_pred=1.1794e+01, psi_term=9.4063e+00, obj=106379589.123026, solved_in=0.008s
# step 103: psi_curr=1.1812e+01, min_psi_pred=1.1792e+01, psi_term=9.4017e+00, obj=106045888.694928, solved_in=0.007s
# step 104: psi_curr=1.1811e+01, min_psi_pred=1.1790e+01, psi_term=9.3972e+00, obj=105717180.946277, solved_in=0.007s
# step 105: psi_curr=1.1809e+01, min_psi_pred=1.1789e+01, psi_term=9.3927e+00, obj=105393271.953743, solved_in=0.007s
# step 106: psi_curr=1.1807e+01, min_psi_pred=1.1787e+01, psi_term=9.3882e+00, obj=105073974.477097, solved_in=0.008s
# step 107: psi_curr=1.1805e+01, min_psi_pred=1.1785e+01, psi_term=9.3838e+00, obj=104759107.706953, solved_in=0.007s
# step 108: psi_curr=1.1803e+01, min_psi_pred=1.1783e+01, psi_term=9.3794e+00, obj=104448497.025327, solved_in=0.007s
# step 109: psi_curr=1.1801e+01, min_psi_pred=1.1781e+01, psi_term=9.3751e+00, obj=104141973.778199, solved_in=0.008s
# step 110: psi_curr=1.1800e+01, min_psi_pred=1.1780e+01, psi_term=9.3708e+00, obj=103839375.059352, solved_in=0.007s
# step 111: psi_curr=1.1798e+01, min_psi_pred=1.1778e+01, psi_term=9.3665e+00, obj=103540543.504790, solved_in=0.007s
# step 112: psi_curr=1.1796e+01, min_psi_pred=1.1776e+01, psi_term=9.3623e+00, obj=103245327.097092, solved_in=0.007s
# step 113: psi_curr=1.1794e+01, min_psi_pred=1.1775e+01, psi_term=9.3582e+00, obj=102953578.979104, solved_in=0.007s
# step 114: psi_curr=1.1792e+01, min_psi_pred=1.1773e+01, psi_term=9.3541e+00, obj=102665157.276413, solved_in=0.007s
# step 115: psi_curr=1.1791e+01, min_psi_pred=1.1771e+01, psi_term=9.3500e+00, obj=102379924.928077, solved_in=0.007s
# step 116: psi_curr=1.1789e+01, min_psi_pred=1.1770e+01, psi_term=9.3461e+00, obj=102097749.525130, solved_in=0.007s
# step 117: psi_curr=1.1787e+01, min_psi_pred=1.1768e+01, psi_term=9.3421e+00, obj=101818503.156403, solved_in=0.008s
# step 118: psi_curr=1.1785e+01, min_psi_pred=1.1766e+01, psi_term=9.3383e+00, obj=101542062.261242, solved_in=0.007s
# step 119: psi_curr=1.1784e+01, min_psi_pred=1.1765e+01, psi_term=9.3345e+00, obj=101268307.488721, solved_in=0.008s
# step 120: psi_curr=1.1782e+01, min_psi_pred=1.1763e+01, psi_term=9.3308e+00, obj=100997123.562987, solved_in=0.007s
# step 121: psi_curr=1.1780e+01, min_psi_pred=1.1762e+01, psi_term=9.3271e+00, obj=100728399.154378, solved_in=0.007s
# step 122: psi_curr=1.1779e+01, min_psi_pred=1.1760e+01, psi_term=9.3235e+00, obj=100462026.756000, solved_in=0.006s
# step 123: psi_curr=1.1777e+01, min_psi_pred=1.1759e+01, psi_term=9.3200e+00, obj=100197902.565460, solved_in=0.007s
# step 124: psi_curr=1.1775e+01, min_psi_pred=1.1757e+01, psi_term=9.3166e+00, obj=99935926.371452, solved_in=0.010s
# step 125: psi_curr=1.1774e+01, min_psi_pred=1.1756e+01, psi_term=9.3132e+00, obj=99676001.444957, solved_in=0.013s
# step 126: psi_curr=1.1772e+01, min_psi_pred=1.1755e+01, psi_term=9.3099e+00, obj=99418034.434777, solved_in=0.015s
# step 127: psi_curr=1.1771e+01, min_psi_pred=1.1753e+01, psi_term=9.3067e+00, obj=99161935.267190, solved_in=0.014s
# step 128: psi_curr=1.1769e+01, min_psi_pred=1.1752e+01, psi_term=9.3036e+00, obj=98907617.049498, solved_in=0.013s
# step 129: psi_curr=1.1768e+01, min_psi_pred=1.1751e+01, psi_term=9.3005e+00, obj=98654995.977248, solved_in=0.012s
# step 130: psi_curr=1.1766e+01, min_psi_pred=1.1750e+01, psi_term=9.2976e+00, obj=98403991.244964, solved_in=0.010s
# step 131: psi_curr=1.1765e+01, min_psi_pred=1.1748e+01, psi_term=9.2947e+00, obj=98154524.960164, solved_in=0.012s
# step 132: psi_curr=1.1763e+01, min_psi_pred=1.1747e+01, psi_term=9.2919e+00, obj=97906522.060524, solved_in=0.012s
# step 133: psi_curr=1.1762e+01, min_psi_pred=1.1746e+01, psi_term=9.2892e+00, obj=97659910.234016, solved_in=0.011s
# step 134: psi_curr=1.1761e+01, min_psi_pred=1.1745e+01, psi_term=9.2866e+00, obj=97414619.841859, solved_in=0.012s
# step 135: psi_curr=1.1759e+01, min_psi_pred=1.1744e+01, psi_term=9.2840e+00, obj=97170583.844160, solved_in=0.013s
# step 136: psi_curr=1.1758e+01, min_psi_pred=1.1743e+01, psi_term=9.2816e+00, obj=96927737.728081, solved_in=0.012s
# step 137: psi_curr=1.1757e+01, min_psi_pred=1.1742e+01, psi_term=9.2793e+00, obj=96686019.438445, solved_in=0.014s
# step 138: psi_curr=1.1756e+01, min_psi_pred=1.1741e+01, psi_term=9.2770e+00, obj=96445369.310614, solved_in=0.011s
# step 139: psi_curr=1.1755e+01, min_psi_pred=1.1740e+01, psi_term=9.2749e+00, obj=96205730.005570, solved_in=0.011s
# step 140: psi_curr=1.1753e+01, min_psi_pred=1.1739e+01, psi_term=9.2728e+00, obj=95967046.447062, solved_in=0.011s
# step 141: psi_curr=1.1752e+01, min_psi_pred=1.1738e+01, psi_term=9.2708e+00, obj=95729265.760740, solved_in=0.011s
# step 142: psi_curr=1.1751e+01, min_psi_pred=1.1737e+01, psi_term=9.2690e+00, obj=95492337.215160, solved_in=0.011s
# step 143: psi_curr=1.1750e+01, min_psi_pred=1.1736e+01, psi_term=9.2672e+00, obj=95256212.164598, solved_in=0.010s
# step 144: psi_curr=1.1749e+01, min_psi_pred=1.1736e+01, psi_term=9.2655e+00, obj=95020843.993560, solved_in=0.012s
# step 145: psi_curr=1.1748e+01, min_psi_pred=1.1735e+01, psi_term=9.2639e+00, obj=94786188.062931, solved_in=0.013s
# step 146: psi_curr=1.1747e+01, min_psi_pred=1.1734e+01, psi_term=9.2625e+00, obj=94552201.657678, solved_in=0.012s
# step 147: psi_curr=1.1746e+01, min_psi_pred=1.1734e+01, psi_term=9.2611e+00, obj=94318843.936039, solved_in=0.011s
# step 148: psi_curr=1.1746e+01, min_psi_pred=1.1733e+01, psi_term=9.2598e+00, obj=94086075.880124, solved_in=0.011s
# step 149: psi_curr=1.1745e+01, min_psi_pred=1.1732e+01, psi_term=9.2586e+00, obj=93853860.247882, solved_in=0.010s
# step 150: psi_curr=1.1744e+01, min_psi_pred=1.1732e+01, psi_term=9.2575e+00, obj=93622161.526352, solved_in=0.011s
# step 151: psi_curr=1.1743e+01, min_psi_pred=1.1731e+01, psi_term=9.2566e+00, obj=93390945.886166, solved_in=0.011s
# step 152: psi_curr=1.1743e+01, min_psi_pred=1.1731e+01, psi_term=9.2557e+00, obj=93160181.137222, solved_in=0.013s
# step 153: psi_curr=1.1742e+01, min_psi_pred=1.1731e+01, psi_term=9.2549e+00, obj=92929836.685509, solved_in=0.013s
# step 154: psi_curr=1.1741e+01, min_psi_pred=1.1730e+01, psi_term=9.2543e+00, obj=92699883.491004, solved_in=0.016s
# step 155: psi_curr=1.1741e+01, min_psi_pred=1.1730e+01, psi_term=9.2537e+00, obj=92470294.026629, solved_in=0.011s
# step 156: psi_curr=1.1740e+01, min_psi_pred=1.1730e+01, psi_term=9.2532e+00, obj=92241042.238191, solved_in=0.012s
# step 157: psi_curr=1.1740e+01, min_psi_pred=1.1729e+01, psi_term=9.2528e+00, obj=92012103.505294, solved_in=0.013s
# ...
# step 1855: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=12.205126, solved_in=0.012s
# step 1856: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=12.157544, solved_in=0.010s
# step 1857: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=12.110716, solved_in=0.011s
# step 1858: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=12.064629, solved_in=0.010s
# step 1859: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=12.019275, solved_in=0.010s
# step 1860: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.974642, solved_in=0.012s
# step 1861: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.930720, solved_in=0.015s
# step 1862: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.887499, solved_in=0.010s
# step 1863: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.844968, solved_in=0.012s
# step 1864: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.803117, solved_in=0.010s
# step 1865: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.761934, solved_in=0.010s
# step 1866: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.721410, solved_in=0.016s
# step 1867: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.681532, solved_in=0.009s
# step 1868: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.642289, solved_in=0.011s
# step 1869: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.603671, solved_in=0.010s
# step 1870: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.565666, solved_in=0.010s
# step 1871: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.528262, solved_in=0.011s
# step 1872: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.491449, solved_in=0.011s
# step 1873: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.455215, solved_in=0.012s
# step 1874: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.419549, solved_in=0.011s
# step 1875: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.384442, solved_in=0.010s
# step 1876: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.349882, solved_in=0.010s
# step 1877: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.315861, solved_in=0.011s
# step 1878: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.282370, solved_in=0.012s
# step 1879: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.249400, solved_in=0.011s
# step 1880: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.216944, solved_in=0.011s
# step 1881: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.184993, solved_in=0.012s
# step 1882: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.153542, solved_in=0.011s
# step 1883: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.122584, solved_in=0.011s
# step 1884: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.092112, solved_in=0.012s
# step 1885: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.062123, solved_in=0.012s
# step 1886: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.032609, solved_in=0.011s
# step 1887: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=11.003566, solved_in=0.012s
# step 1888: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.974988, solved_in=0.012s
# step 1889: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.946870, solved_in=0.012s
# step 1890: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.919205, solved_in=0.016s
# step 1891: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.891988, solved_in=0.012s
# step 1892: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.865212, solved_in=0.009s
# step 1893: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.838869, solved_in=0.009s
# step 1894: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.812952, solved_in=0.009s
# step 1895: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.787454, solved_in=0.018s
# step 1896: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.762364, solved_in=0.013s
# step 1897: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.737676, solved_in=0.012s
# step 1898: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.713380, solved_in=0.012s
# step 1899: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.689466, solved_in=0.012s
# step 1900: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.665927, solved_in=0.029s
# step 1901: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.642753, solved_in=0.020s
# step 1902: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.619936, solved_in=0.013s
# step 1903: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.597468, solved_in=0.013s
# step 1904: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.575342, solved_in=0.015s
# step 1905: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.553552, solved_in=0.011s
# step 1906: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.532092, solved_in=0.011s
# step 1907: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.510957, solved_in=0.012s
# step 1908: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.490144, solved_in=0.012s
# step 1909: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.469650, solved_in=0.009s
# step 1910: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.449472, solved_in=0.012s
# step 1911: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.429609, solved_in=0.012s
# step 1912: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.410060, solved_in=0.012s
# step 1913: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.390823, solved_in=0.012s
# step 1914: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.371898, solved_in=0.012s
# step 1915: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.353284, solved_in=0.011s
# step 1916: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.334978, solved_in=0.013s
# step 1917: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.316980, solved_in=0.012s
# step 1918: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.299286, solved_in=0.013s
# step 1919: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.281893, solved_in=0.012s
# step 1920: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.264796, solved_in=0.010s
# step 1921: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.247990, solved_in=0.009s
# step 1922: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.231467, solved_in=0.010s
# step 1923: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.215221, solved_in=0.012s
# step 1924: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.199243, solved_in=0.022s
# step 1925: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.183524, solved_in=0.011s
# step 1926: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.168055, solved_in=0.011s
# step 1927: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.152826, solved_in=0.014s
# step 1928: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.137828, solved_in=0.012s
# step 1929: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.123052, solved_in=0.012s
# step 1930: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.108490, solved_in=0.015s
# step 1931: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.094136, solved_in=0.012s
# step 1932: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.079982, solved_in=0.012s
# step 1933: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.066025, solved_in=0.012s
# step 1934: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.052261, solved_in=0.011s
# step 1935: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.038689, solved_in=0.011s
# step 1936: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.025309, solved_in=0.012s
# step 1937: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=10.012122, solved_in=0.011s
# step 1938: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.999130, solved_in=0.013s
# step 1939: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.986337, solved_in=0.012s
# step 1940: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.973746, solved_in=0.011s
# step 1941: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.961363, solved_in=0.011s
# step 1942: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.949191, solved_in=0.012s
# step 1943: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.937232, solved_in=0.011s
# step 1944: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.925491, solved_in=0.011s
# step 1945: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.913968, solved_in=0.013s
# step 1946: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.902663, solved_in=0.012s
# step 1947: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.891574, solved_in=0.012s
# step 1948: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.880697, solved_in=0.009s
# step 1949: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.870027, solved_in=0.012s
# step 1950: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.859555, solved_in=0.011s
# step 1951: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.849272, solved_in=0.014s
# step 1952: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.839167, solved_in=0.013s
# step 1953: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.829230, solved_in=0.031s
# step 1954: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.819447, solved_in=0.011s
# step 1955: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.809806, solved_in=0.011s
# step 1956: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.800295, solved_in=0.013s
# step 1957: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.790904, solved_in=0.012s
# step 1958: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.781623, solved_in=0.012s
# step 1959: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.772444, solved_in=0.011s
# step 1960: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.763361, solved_in=0.012s
# step 1961: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.754373, solved_in=0.012s
# step 1962: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.745479, solved_in=0.011s
# step 1963: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.736682, solved_in=0.012s
# step 1964: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.727987, solved_in=0.011s
# step 1965: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.719400, solved_in=0.011s
# step 1966: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.710933, solved_in=0.012s
# step 1967: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.702594, solved_in=0.011s
# step 1968: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.694397, solved_in=0.012s
# step 1969: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.686351, solved_in=0.010s
# step 1970: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.678467, solved_in=0.011s
# step 1971: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.670755, solved_in=0.013s
# step 1972: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.663223, solved_in=0.012s
# step 1973: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.655874, solved_in=0.012s
# step 1974: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.648710, solved_in=0.010s
# step 1975: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.641730, solved_in=0.012s
# step 1976: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.634927, solved_in=0.010s
# step 1977: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.628293, solved_in=0.013s
# step 1978: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.621815, solved_in=0.012s
# step 1979: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.615479, solved_in=0.011s
# step 1980: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.609266, solved_in=0.011s
# step 1981: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.603157, solved_in=0.014s
# step 1982: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.597132, solved_in=0.023s
# step 1983: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.591173, solved_in=0.012s
# step 1984: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.585259, solved_in=0.012s
# step 1985: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.579376, solved_in=0.013s
# step 1986: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.573509, solved_in=0.011s
# step 1987: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.567649, solved_in=0.013s
# step 1988: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.561791, solved_in=0.011s
# step 1989: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.555934, solved_in=0.012s
# step 1990: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.550084, solved_in=0.014s
# step 1991: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.544248, solved_in=0.014s
# step 1992: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.538442, solved_in=0.013s
# step 1993: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.532683, solved_in=0.016s
# step 1994: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.526991, solved_in=0.011s
# step 1995: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.521388, solved_in=0.016s
# step 1996: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.515900, solved_in=0.012s
# step 1997: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.510547, solved_in=0.011s
# step 1998: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.505353, solved_in=0.011s
# step 1999: psi_curr=1.6000e+01, min_psi_pred=1.6000e+01, psi_term=1.5630e+01, obj=9.500333, solved_in=0.011s
# Result: not reached steps: 2001

# %%
        # # plot trajectories
        # plt.figure(figsize=(8,6))
        # for r in all_results:
        #     tr = r['traj']
        #     plt.plot(tr[:,0], tr[:,1], '-o', markersize=3)
        #     # start point
        #     plt.plot(tr[0,0], tr[0,1],
        #             marker='s', markersize=2,
        #             color='green', label=None)

        #     # end point
        #     plt.plot(tr[-1,0], tr[-1,1],
        #             marker='*', markersize=2,
        #             color='red', label=None)        
        # plot psi=0 and phi=0 contours
        # xs = np.linspace(-2.5, 2.5, 250)
        # ys = np.linspace(-2.5, 2.5, 250)
        # XX, YY = np.meshgrid(xs, ys)
        # ZZ = np.zeros_like(XX)
        # PH = np.zeros_like(XX)
        # PH_new = np.zeros_like(XX)
        # for ii in range(XX.shape[0]):
        #     for jj in range(XX.shape[1]):
        #         ZZ[ii,jj] = float(psi_func_numpy(XX[ii,jj], YY[ii,jj]))
        #         PH[ii,jj] = float(phi_func_numpy(XX[ii,jj], YY[ii,jj]))
                

        # Psi_vals = np.zeros_like(XX)

        # for ii in range(XX.shape[0]):
        #     x_batch = XX[ii, :]
        #     y_batch = YY[ii, :]

        #     # Build full 4×N state input
        #     full_state = np.vstack([
        #         x_batch,                # x0
        #         y_batch,                # x1
        #         np.zeros_like(x_batch), # theta = 0
        #         np.zeros_like(x_batch)  # v = 0
        #     ])

        #     Psi_vals[ii, :] = np.array(Psi_fun_cas(full_state)).flatten()

        # plt.contour(XX, YY, Psi_vals, levels=[0.0], colors='blue', linestyles='-.', linewidths=1.2)                                 
        # plt.contour(XX, YY, ZZ, levels=[0.0], colors='k', linewidths=1.2)
        # plt.contour(XX, YY, PH, levels=[0.0], colors='r', linestyles='--')
        # plt.title("Function contours")
        # plt.xlabel('x'); plt.ylabel('y'); plt.axis('equal'); plt.grid(True)
        # plt.show()
from functional import BetterColor, simulate
px = 1 / plt.rcParams["figure.dpi"]
fig, ax = plt.subplots(figsize=(610 * px, 600 * px), layout="constrained")
fig.set_dpi(200)

            

    # vector field of the single-integrator system with k1 controller
k1 = sp.Matrix([k1_0, k1_1])
k1f = sp.lambdify(y, k1, "numpy")
Z = k1f(XX, YY).squeeze()
print(Z.shape, "z")
ax.streamplot(
        XX,
        YY,
        Z[0],
        Z[1],
        density=0.5,
        # color="#404040",  # medium gray tone
        # color="#2F4F4F",
        color=BetterColor.gray0(0.7),
        linewidth=1,
        arrowstyle="->",
        arrowsize=1.2,
    )

ax.contourf(
        XX,
        YY,
        ZZ,
        levels=[0, +np.inf],
        colors=["#e6f2ff"],  # very light blue
        # hatches=["..."],  # dot pattern
        alpha=0.3,
        zorder=1,
    )

ax.contour(
        XX,
        YY,
        ZZ,
        levels=[0],
        colors=["#2166ac"],  # academic blue
        linewidths=2,
        zorder=2,
    )

ax.contourf(
        XX,
        YY,
        PH,
        levels=[-np.inf, 0],
        colors=["#fee0d2"],  # light coral
        # hatches=["////"],  # diagonal line pattern
        alpha=1,
        zorder=100,
    )
ax.contour(
        XX,
        YY,
        PH,
        levels=[0],
        colors=["#b2182b"],  # dark red
        linewidths=2,
        zorder=101,
    )

line_style = {
        # "color": "#404040",  # use academic gray instead of pure black
        "color": "#2166ac",
        "linestyle": "-",  # use solid line instead of dash-dot line
        "alpha": 0.2,
        "linewidth": 0.5,
        "solid_capstyle": "round",
    }

    # plot each output trajectory
    # for i in range(len(traj_y)):
    #     this_traj_y = traj_y[i]
for r in all_results:
            tr = r['traj']    
            # trajectory
            plt.plot(
                tr[:, 0],
                tr[:, 1],
                # **line_style,
                color="black",
                linestyle="--",
                linewidth=1.5,
                alpha=0.5,
                zorder=5,
                # "red",
                # linewidth=1.0,
                # alpha=0.4,
                # zorder=2,
            )
            # start point
            # plt.scatter(
            #     this_traj_y[0, 0], this_traj_y[0, 1], s=2, c="black", alpha=0.3, zorder=3
            # )
            plt.scatter(
                tr[0, 0],
                tr[0, 1],
                s=50,
                # c="#d73027",  # IEEE red
                c=BetterColor.orange3(),
                # marker="^",  # triangle
                # edgecolor="w",  # white edge
                linewidth=0.3,
                zorder=20,
            )
            # end point
            # plt.scatter(this_traj_y[-1, 0], this_traj_y[-1, 1], s=2.5, c="red", zorder=3)
            plt.scatter(
                tr[-1, 0],
                tr[-1, 1],
                s=50,
                linewidth=0.5,
                # c="#313695",  # dark blue
                # c="#8B008B",
                # c="#4daf4a",
                c=BetterColor.green0(),
                # edgecolors="#984ea3",
                # marker="o",  # circle
                # marker=(5, 1, 0),
                marker="x",
                # edgecolor="#ffffbf",  # light yellow edge
                # linewidth=0.4,
                zorder=200,
            )

this_fontsize = 35

ax.text(0.3, 1.65, "$\mathcal{C}$", zorder=100, fontsize=this_fontsize)
ax.text(-2.5, -0, "$\mathcal{X}^r$", zorder=100, fontsize=this_fontsize)
    # temp_str = "$\mathcal{C}_{\Psi," + str(mu_1) + "}$"
        # ax.text(0.867, 1.782, temp_str, zorder=100, fontsize=this_fontsize - 2)

ax.xaxis.set_tick_params(labelsize=20, width=1)
ax.yaxis.set_tick_params(labelsize=20, width=1)
plt.xlabel("$y_1$", fontsize=this_fontsize - 5)
plt.ylabel("$y_2$", fontsize=this_fontsize - 5)

plt.show()
# Out:
# (2, 100, 100) z
# C:\Users\nisha\AppData\Local\Temp\ipykernel_20796\4286551092.py:150: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(
# C:\Users\nisha\AppData\Local\Temp\ipykernel_20796\4286551092.py:163: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(
